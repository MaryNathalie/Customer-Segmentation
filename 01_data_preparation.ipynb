# %%
import pandas as pd
import os

from ucimlrepo import fetch_ucirepo 
import re

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

os.makedirs('data', exist_ok=True)

# %% [markdown]
# ### **Fetching the Dataset**

# %%
# Fetch the Online Retail dataset from UCI Machine Learning Repository
online_retail = fetch_ucirepo(id=352)

# %%
# dataset keys
online_retail.keys()
# Out:
# dict_keys(['data', 'metadata', 'variables'])

# %%
# variables information
online_retail.variables
# Out:
#           name     role         type demographic  \
# 0    InvoiceNo       ID  Categorical        None
# 1    StockCode       ID  Categorical        None
# 2  Description  Feature  Categorical        None
# 3     Quantity  Feature      Integer        None
# 4  InvoiceDate  Feature         Date        None
# 5    UnitPrice  Feature   Continuous        None
# 6   CustomerID  Feature  Categorical        None
# 7      Country  Feature  Categorical        None
#
#                                                                                                                          description  \
# 0  a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation
# 1                                                               a 5-digit integral number uniquely assigned to each distinct product
# 2                                                                                                                       product name
# 3                                                                              the quantities of each product (item) per transaction
# 4                                                                               the day and time when each transaction was generated
# 5                                                                                                             product price per unit
# 6                                                                       a 5-digit integral number uniquely assigned to each customer
# 7                                                                                the name of the country where each customer resides
#
#       units missing_values
# 0      None             no
# 1      None             no
# 2      None             no
# 3      None             no
# 4      None             no
# 5  sterling             no
# 6      None             no
# 7      None             no

# %%
# metadata 
online_retail.metadata
# Out:
# {'uci_id': 352,
#  'name': 'Online Retail',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/352/online+retail',
#  'data_url': 'https://archive.ics.uci.edu/static/public/352/data.csv',
#  'abstract': 'This is a transactional data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.',
#  'area': 'Business',
#  'tasks': ['Classification', 'Clustering'],
#  'characteristics': ['Multivariate', 'Sequential', 'Time-Series'],
#  'num_instances': 541909,
#  'num_features': 6,
#  'feature_types': ['Integer', 'Real'],
#  'demographics': [],
#  'target_col': None,
#  'index_col': ['InvoiceNo', 'StockCode'],
#  'has_missing_values': 'no',
#  'missing_values_symbol': None,
#  'year_of_dataset_creation': 2015,
#  'last_updated': 'Mon Oct 21 2024',
#  'dataset_doi': '10.24432/C5BW33',
#  'creators': ['Daqing Chen'],
#  'intro_paper': {'ID': 361,
#   'type': 'NATIVE',
#   'title': 'Data mining for the online retail industry: A case study of RFM model-based customer segmentation using data mining',
#   'authors': 'Daqing Chen, Sai Laing Sain, Kun Guo',
#   'venue': 'Journal of Database Marketing and Customer Strategy Management, Vol. 19, No. 3',
#   'year': 2012,
#   'journal': None,
#   'DOI': '10.1057/dbm.2012.17',
#   'URL': 'https://www.semanticscholar.org/paper/e43a5a90fa33d419df42e485099f8f08badf2149',
#   'sha': None,
#   'corpus': None,
#   'arxiv': None,
#   'mag': None,
#   'acl': None,
#   'pmid': None,
#   'pmcid': None},
#  'additional_info': {'summary': 'This is a transactional data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.',
#   'purpose': None,
#   'funded_by': None,
#   'instances_represent': None,
#   'recommended_data_splits': None,
#   'sensitive_data': None,
#   'preprocessing_description': None,
#   'variable_info': "InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation. \nStockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.\nDescription: Product (item) name. Nominal.\nQuantity: The quantities of each product (item) per transaction. Numeric.\t\nInvoiceDate: Invoice Date and time. Numeric, the day and time when each transaction was generated.\nUnitPrice: Unit price. Numeric, Product price per unit in sterling.\nCustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.\nCountry: Country name. Nominal, the name of the country where each customer resides. ",
#   'citation': None}}

# %%
# data keys
online_retail.data.keys()
# Out:
# dict_keys(['ids', 'features', 'targets', 'original', 'headers'])

# %%
# column headers
online_retail.data.headers
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# original data
df = online_retail.data.original
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### **Checking Datatypes**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Convert CustomerID to object type
df = df.astype({'CustomerID': 'object'})
# Convert InvoiceDate to datetime type
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%m/%d/%Y %H:%M')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Statistical summary of numerical columns
df.select_dtypes(include=['int64', 'float64']).describe().T
# Out:
#               count      mean         std       min   25%   50%    75%  \
# Quantity   541909.0  9.552250  218.081158 -80995.00  1.00  3.00  10.00
# UnitPrice  541909.0  4.611114   96.759853 -11062.06  1.25  2.08   4.13
#
#                max
# Quantity   80995.0
# UnitPrice  38970.0

# %%
# Statistical summary of categorical columns
df.describe(include='object').T
# Out:
#                 count  unique                                 top    freq
# InvoiceNo      541909   25900                              573585    1114
# StockCode      541909    4070                              85123A    2313
# Description    540455    4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# CustomerID   406829.0  4372.0                             17841.0  7983.0
# Country        541909      38                      United Kingdom  495478

# %% [markdown]
# ### **Cleaning Dataset**

# %% [markdown]
# #### *1. Handling Missing Data*

# %%
# Count the number of missing values per column
missing_count = df.isnull().sum()

# Calculate the percentage of missing values per column
missing_percentage = round((df.isnull().sum() / len(df)) * 100, 2)

# %%
print("Missing Data Count:")
print(missing_count)

print("\nMissing Data Percentage:")
print(missing_percentage)
# Out:
# Missing Data Count:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
#
# Missing Data Percentage:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# dtype: float64

# %% [markdown]
# **Note:**
# *It is important to have accurate Customer IDs for customer segmentation and recommendation system because clustering is based upon the behavior of each unique customer. Hence, instead of imputing, we decided to remove rows with missing Customer IDs.*

# %%
print(f"Number of rows before removing missing CustomerID: {df.shape[0]}")

# Remove rows where CustomerID is missing
df = df.dropna(subset=['CustomerID'])

print(f"Number of rows after removing missing CustomerID: {df.shape[0]}")
# Out:
# Number of rows before removing missing CustomerID: 541909
# Number of rows after removing missing CustomerID: 406829

# %%
# Verifying the removal of missing values
missing_count_after = df.isnull().sum()
print("Missing Data Count After Removal:")
print(missing_count_after)
# Out:
# Missing Data Count After Removal:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# #### *2. Handling Duplicates*

# %%
# Count the number of duplicate rows
duplicate_count = df.duplicated().sum()

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 5225

# %% [markdown]
# **Note:**
# *These are completely identical rows, including unique identifiers like InvoiceNo, StockCode, and CustomerID and dates like InvoiceDate. Hence, they are most likely be data recording errors that we should remove.*

# %%
print(f"Number of rows before removing duplicates: {df.shape[0]}")

# Remove duplicate rows
df.drop_duplicates(inplace=True)

print(f"Number of rows after removing duplicates: {df.shape[0]}")
# Out:
# Number of rows before removing duplicates: 406829
# Number of rows after removing duplicates: 401604

# %% [markdown]
# #### *3. Checking InvoiceNo*

# %% [markdown]
# ##### *3.a. Checking Number of Characters in InvoiceNo*

# %%
# Count the number of numeric characters in each InvoiceNo
df_play = df.copy()
df_play['InvoiceNo_NumericLength'] = df_play['InvoiceNo'].apply(lambda x: sum(c.isdigit() for c in str(x)))

# Count unique InvoiceNo based on their numeric length
numeric_length_counts = df_play.groupby('InvoiceNo_NumericLength')['InvoiceNo'].nunique()

print("Unique InvoiceNo counts based on numeric length:")
display(numeric_length_counts)
# Out:
# Unique InvoiceNo counts based on numeric length:
# InvoiceNo_NumericLength
# 6    22190
# Name: InvoiceNo, dtype: int64

# %%
# Count the character length of each InvoiceNo
df_play['InvoiceNo_Length'] = df_play['InvoiceNo'].apply(lambda x: len(str(x)))

# Count unique InvoiceNo based on their character length
invoice_length_counts = df_play.groupby('InvoiceNo_Length')['InvoiceNo'].nunique()

print("Unique InvoiceNo counts based on character length:")
display(invoice_length_counts)
# Out:
# Unique InvoiceNo counts based on character length:
# InvoiceNo_Length
# 6    18536
# 7     3654
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ##### *3.b. Handling Cancelled Transactions based on InvoiceNo*

# %%
# Add a "Status" column based on the "InvoiceNo" column
df['Status'] = df['InvoiceNo'].apply(lambda x: 'Cancelled' if str(x).startswith('C') else 'Completed')

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country     Status
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom  Completed
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom  Completed
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed

# %%
# Filter data for Completed and Cancelled statuses
df_completed = df[df['Status'] == 'Completed']
df_cancelled = df[df['Status'] == 'Cancelled']

print("Numerical Statistics for Status = Completed:")
display(df_completed.select_dtypes(include=['int64', 'float64']).describe().T)

print("\nNumerical Statistics for Status = Cancelled:")
display(df_cancelled.select_dtypes(include=['int64', 'float64']).describe().T)
# Out:
# Numerical Statistics for Status = Completed:
#               count       mean         std  min   25%   50%    75%       max
# Quantity   392732.0  13.153718  181.588420  1.0  2.00  6.00  12.00  80995.00
# UnitPrice  392732.0   3.125596   22.240725  0.0  1.25  1.95   3.75   8142.75
# Numerical Statistics for Status = Cancelled:
#             count       mean          std       min   25%   50%   75%      max
# Quantity   8872.0 -30.774910  1172.249902 -80995.00 -6.00 -2.00 -1.00     -1.0
# UnitPrice  8872.0  18.899512   445.190864      0.01  1.45  2.95  4.95  38970.0

# %%
# Row with maximum Quantity
max_quantity_row = df[df['Quantity'] == df['Quantity'].max()]
print("Row with Maximum Quantity:")
display(max_quantity_row)

# Row with minimum Quantity
min_quantity_row = df[df['Quantity'] == df['Quantity'].min()]
print("\nRow with Minimum Quantity:")
display(min_quantity_row)
# Out:
# Row with Maximum Quantity:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice CustomerID         Country     Status
# 540421 2011-12-09 09:15:00       2.08    16446.0  United Kingdom  Completed
# Row with Minimum Quantity:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice CustomerID         Country     Status
# 540422 2011-12-09 09:27:00       2.08    16446.0  United Kingdom  Cancelled

# %%
# Calculate the percentage of Cancelled transactions
cancelled_percentage = round((len(df_cancelled) / len(df)) * 100,2)

print(f"Percentage of Cancelled Transactions: {cancelled_percentage:.2f}%")
# Out:
# Percentage of Cancelled Transactions: 2.21%

# %% [markdown]
# #### *4. Checking StockCode*

# %% [markdown]
# ##### *4.a. Checking Number of Characters in StockCode*

# %%
# Count the number of numeric characters in each StockCode
df_play = df.copy()
df_play['StockCode_NumericLength'] = df_play['StockCode'].apply(lambda x: sum(c.isdigit() for c in str(x)))

# Count unique StockCode based on their numeric length
stockcode_numeric_length_counts = df_play.groupby('StockCode_NumericLength')['StockCode'].nunique()

print("Unique StockCode counts based on numeric length:")
display(stockcode_numeric_length_counts)
# Out:
# Unique StockCode counts based on numeric length:
# StockCode_NumericLength
# 0       7
# 1       1
# 5    3676
# Name: StockCode, dtype: int64

# %%
# Filter rows where StockCode_NumericLength is not equal to 5
filtered_data = df_play[df_play['StockCode_NumericLength'] != 5]

# Group by StockCode and Description
grouped_data = filtered_data.groupby(['StockCode', 'Description']).agg(
    Unique_InvoiceNo_Cancelled=('InvoiceNo', lambda x: x[filtered_data['Status'] == 'Cancelled'].nunique()),
    Unique_InvoiceNo_Completed=('InvoiceNo', lambda x: x[filtered_data['Status'] == 'Completed'].nunique()),
    Quantity_Cancelled=('Quantity', lambda x: x[filtered_data['Status'] == 'Cancelled'].abs().sum()),
    Quantity_Completed=('Quantity', lambda x: x[filtered_data['Status'] == 'Completed'].sum()),
    Price_Cancelled=('UnitPrice', lambda x: (x[filtered_data['Status'] == 'Cancelled'] * filtered_data.loc[filtered_data['Status'] == 'Cancelled', 'Quantity']).sum()),
    Price_Completed=('UnitPrice', lambda x: (x[filtered_data['Status'] == 'Completed'] * filtered_data.loc[filtered_data['Status'] == 'Completed', 'Quantity']).sum())
).reset_index()

# Calculate Net Quantity (Completed - Cancelled)
grouped_data['Net_Quantity'] = grouped_data['Quantity_Completed'] - grouped_data['Quantity_Cancelled']

# Calculate Net Unit Price (Completed - Cancelled)
grouped_data['Net_Price'] = grouped_data['Price_Completed'] + grouped_data['Price_Cancelled']

# Display the grouped data
print("Rows with StockCode_NumericLength not equal to 5 and their aggregated metrics:")
display(grouped_data)
# Out:
# Rows with StockCode_NumericLength not equal to 5 and their aggregated metrics:
#       StockCode                 Description  Unique_InvoiceNo_Cancelled  \
# 0  BANK CHARGES                Bank Charges                           0
# 1            C2                    CARRIAGE                           1
# 2          CRUK             CRUK Commission                          16
# 3             D                    Discount                          65
# 4           DOT              DOTCOM POSTAGE                           0
# 5             M                      Manual                         154
# 6          PADS  PADS TO MATCH ALL CUSHIONS                           0
# 7          POST                     POSTAGE                          95
#
#    Unique_InvoiceNo_Completed  Quantity_Cancelled  Quantity_Completed  \
# 0                          11                   0                  12
# 1                         133                   1                 134
# 2                           0                  16                   0
# 3                           0                1194                   0
# 4                          16                   0                  16
# 5                         258                3995                6939
# 6                           4                   0                   4
# 7                        1099                 118                3120
#
#    Price_Cancelled  Price_Completed  Net_Quantity  Net_Price
# 0             0.00          165.001            12    165.001
# 1           -50.00         6686.000           133   6636.000
# 2         -7933.43            0.000           -16  -7933.430
# 3         -5696.22            0.000         -1194  -5696.220
# 4             0.00        11906.360            16  11906.360
# 5       -112165.39        53419.930          2944 -58745.460
# 6             0.00            0.003             4      0.003
# 7        -11093.72        77803.960          3002  66710.240

# %% [markdown]
# **Note:**
#
# - ***BankCharges:** Fees charged by the bank for processing transactions, such as credit card fees or other financial services.*
#
# - ***Carriage:** Shipping or delivery charges for transporting goods to the customer.*
#
# - ***CRUK Commission:** Commission fee related to Cancer Research UK (CRUK), a charity organization. It might be a fee or donation associated with a transaction.*
#
# - ***Discount:** Reduction in the price of goods or services, often applied as a promotion or incentive.*
#
# - ***DOTCOM Postage:** Postage or shipping charges for online (e-commerce) orders, often labeled as "dotcom" to distinguish from in-store purchases.*
#
# - ***Manual:** Manually entered transaction, possibly for adjustments, corrections, or special cases.*
#
# - ***Pads to match all cushions:** Cushion pads or inserts designed to match a specific set of cushions, possibly sold as complementary items.*
#
# - ***Postage:** Cost of shipping or mailing goods to the customer.*

# %%
print(f"Number of rows before removing StockCode_NumericLength <> 5: {df.shape[0]}")

# Remove rows where StockCode_NumericLength is not equal to 5
df = df[df['StockCode'].apply(lambda x: sum(c.isdigit() for c in str(x))) == 5]

print(f"Number of rows after removing StockCode_NumericLength <> 5: {df.shape[0]}")
# Out:
# Number of rows before removing StockCode_NumericLength <> 5: 401604
# Number of rows after removing StockCode_NumericLength <> 5: 399689

# %% [markdown]
# #### *5. Checking Description*

# %% [markdown]
# ##### *5.a. Handling Descriptions with lower-case letters*

# %%
# Filter rows where Description contains lowercase letters
filtered_data = df[df['Description'].str.contains('[a-z]', na=False)]

# Group by Description and StockCode
grouped_data = filtered_data.groupby(['Description', 'StockCode']).agg(
    Unique_InvoiceNo=('InvoiceNo', 'nunique'),
    Quantity_Completed=('Quantity', lambda x: x[df.loc[x.index, 'Status'] == 'Completed'].sum()),
    Quantity_Cancelled=('Quantity', lambda x: x[df.loc[x.index, 'Status'] == 'Cancelled'].abs().sum())
).reset_index()

# Calculate Net Quantity (Completed - Cancelled)
grouped_data['Net_Quantity'] = grouped_data['Quantity_Completed'] - grouped_data['Quantity_Cancelled']

# Display the grouped data
print("Descriptions with lowercase letters and their metrics:")
display(grouped_data)
# Out:
# Descriptions with lowercase letters and their metrics:
#                             Description StockCode  Unique_InvoiceNo  \
# 0    3 TRADITIONAl BISCUIT CUTTERS  SET     22965               206
# 1               BAG 125g SWIRLY MARBLES     21703               248
# 2               BAG 250g SWIRLY MARBLES     21704               200
# 3               BAG 500g SWIRLY MARBLES     21705               113
# 4   ESSENTIAL BALM 3.5g TIN IN ENVELOPE     18007                17
# 5       FLOWERS HANDBAG blue and orange    16151A                 3
# 6        FOLK ART GREETING CARD,pack/12    84247K                10
# 7        FRENCH BLUE METAL DOOR SIGN No     22686                75
# 8                 High Resolution Image     23702                 3
# 9         NUMBER TILE COTTAGE GARDEN No     22878                12
# 10         NUMBER TILE VINTAGE FONT No      22889                 7
# 11                    Next Day Carriage     23444                80
# 12       POLYESTER FILLER PAD 30CMx30CM    46000U                26
# 13         POLYESTER FILLER PAD 40x40cm    46000S               185
# 14         POLYESTER FILLER PAD 45x30cm    46000R                37
# 15         POLYESTER FILLER PAD 45x45cm    46000M               134
# 16         POLYESTER FILLER PAD 60x40cm     20964                 1
# 17       POLYESTER FILLER PAD 65CMx65CM    46000P                 5
# 18         THE KING GIFT BAG 25x24x12cm    16162M                 7
#
#     Quantity_Completed  Quantity_Cancelled  Net_Quantity
# 0                 1154                  26          1128
# 1                 9272                  86          9186
# 2                 5004                   5          4999
# 3                 1377                  20          1357
# 4                 5856                   0          5856
# 5                   49                   0            49
# 6                   22                  11            11
# 7                  859                  24           835
# 8                    4                   0             4
# 9                   52                   1            51
# 10                 143                   0           143
# 11                  79                   1            78
# 12                 107                   0           107
# 13                1551                  44          1507
# 14                 101                   0           101
# 15                1008                   1          1007
# 16                   2                   0             2
# 17                  17                   0            17
# 18                  26                   0            26

# %% [markdown]
# **Note:**
#
# *Remove "High Resolution Image" and "Next Day Carriage"*

# %%
print(f"Number of rows before removing specific descriptions: {df.shape[0]}")

# Remove rows with specific descriptions
descriptions_to_remove = ["High Resolution Image", "Next Day Carriage"]
df = df[~df['Description'].isin(descriptions_to_remove)]

print(f"Number of rows after removing specific descriptions: {df.shape[0]}")
# Out:
# Number of rows before removing specific descriptions: 399689
# Number of rows after removing specific descriptions: 399606

# %% [markdown]
# **Note:**
#
# *Convert all descriptions to uppercase for consistency*

# %%
# Convert all descriptions to uppercase
df['Description'] = df['Description'].str.upper()

# %%
# Filter rows where Description contains lowercase letters
filtered_data = df[df['Description'].str.contains('[a-z]', na=False)]

# Group by Description and StockCode
grouped_data = filtered_data.groupby(['Description', 'StockCode']).agg(
    Unique_InvoiceNo=('InvoiceNo', 'nunique'),
    Quantity_Completed=('Quantity', lambda x: x[df.loc[x.index, 'Status'] == 'Completed'].sum()),
    Quantity_Cancelled=('Quantity', lambda x: x[df.loc[x.index, 'Status'] == 'Cancelled'].abs().sum())
).reset_index()

# Calculate Net Quantity (Completed - Cancelled)
grouped_data['Net_Quantity'] = grouped_data['Quantity_Completed'] - grouped_data['Quantity_Cancelled']

# Display the grouped data
print("Descriptions with lowercase letters and their metrics:")
display(grouped_data)
# Out:
# Descriptions with lowercase letters and their metrics:
# Empty DataFrame
# Columns: [Description, StockCode, Unique_InvoiceNo, Quantity_Completed, Quantity_Cancelled, Net_Quantity]
# Index: []

# %% [markdown]
# ##### *5.b. Minor Modifications on Punctuations in Description for Consistency*

# %%
# Filter rows where Description contains punctuations
punctuation_descriptions = df[df['Description'].str.contains(r'[^\w\s]', na=False)]

# Get unique descriptions with punctuations
unique_punctuation_descriptions = punctuation_descriptions['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with Punctuations:")
print(unique_punctuation_descriptions)
# Out:
# Unique Descriptions with Punctuations:
# ['WHITE HANGING HEART T-LIGHT HOLDER' 'RED WOOLLY HOTTIE WHITE HEART.'
#  'GLASS STAR FROSTED T-LIGHT HOLDER' "POPPY'S PLAYHOUSE BEDROOM "
#  "POPPY'S PLAYHOUSE KITCHEN" 'SET/2 RED RETROSPOT TEA TOWELS '
#  "PAPER CHAIN KIT 50'S CHRISTMAS " 'VINTAGE BILLBOARD LOVE/HATE MUG'
#  'WOOD S/3 CABINET ANT WHITE FINISH' 'RED HANGING HEART T-LIGHT HOLDER'
#  'SET/6 RED SPOTTY PAPER PLATES' 'TOMATO CHARLIE+LOLA COASTER SET'
#  'CHARLIE & LOLA WASTEPAPER BIN FLORA'
#  'RED CHARLIE+LOLA PERSONAL DOORSIGN' 'AIRLINE LOUNGE,METAL SIGN'
#  "YOU'RE CONFUSING ME METAL SIGN " 'GIN + TONIC DIET METAL SIGN'
#  'VINTAGE SNAKES & LADDERS' 'COLOUR GLASS T-LIGHT HOLDER HANGING'
#  'BLACK/BLUE POLKADOT UMBRELLA' 'HANGING HEART ZINC T-LIGHT HOLDER'
#  'SET/20 RED RETROSPOT PAPER NAPKINS ' 'SET/6 RED SPOTTY PAPER CUPS'
#  'FANCY FONT BIRTHDAY CARD, ' 'S/6 SEW ON CROCHET FLOWERS'
#  'LADIES & GENTLEMEN METAL SIGN' "I'M ON HOLIDAY METAL SIGN"
#  'SET/10 PINK POLKADOT PARTY CANDLES' 'SET OF 6 T-LIGHTS SNOWMEN'
#  'SET OF 6 T-LIGHTS SANTA' 'LUNCH BAG  BLACK SKULL.'
#  'SET/5 RED RETROSPOT LID GLASS BOWLS' 'VICTORIAN GLASS HANGING T-LIGHT'
#  'SINGLE HEART ZINC T-LIGHT HOLDER' 'SILVER HANGING T-LIGHT HOLDER'
#  'ROTATING SILVER ANGELS T-LIGHT HLDR' "CHILDREN'S SPACEBOY MUG"
#  'BLACK CANDELABRA T-LIGHT HOLDER' 'SET 12 LAVENDER  BOTANICAL T-LIGHTS'
#  "PINK B'FLY C/COVER W BOBBLES" 'AGED GLASS SILVER T-LIGHT HOLDER'
#  'REX CASH+CARRY JUMBO SHOPPER' 'FOLDING UMBRELLA WHITE/RED POLKADOT'
#  'FOLDING UMBRELLA RED/WHITE POLKADOT' 'S/4 VALENTINE DECOUPAGE HEART BOX'
#  "CHILDREN'S APRON DOLLY GIRL " 'CHARLIE + LOLA RED HOT WATER BOTTLE'
#  'SET OF 6 T-LIGHTS TOADSTOOLS' 'ROTATING LEAVES T-LIGHT HOLDER'
#  'S/6 WOODEN SKITTLES IN COTTON BAG' 'HYACINTH BULB T-LIGHT CANDLES'
#  'S/15 SILVER GLASS BAUBLES IN BAG' 'SET/10 RED POLKADOT PARTY CANDLES'
#  'DIAMANTE HAIR GRIP PACK/2 BLACK DIA' 'DIAMANTE HAIR GRIP PACK/2 RUBY'
#  'DIAMANTE HAIR GRIP PACK/2 MONTANA' 'SET/10 BLUE POLKADOT PARTY CANDLES'
#  'CHRISTMAS TREE T-LIGHT HOLDER' 'STAR  T-LIGHT HOLDER '
#  'HEART T-LIGHT HOLDER ' 'SET/9 CHRISTMAS T-LIGHTS SCENTED '
#  'RETROSPOT PARTY BAG + STICKER SET' 'CINAMMON SET OF 9 T-LIGHTS'
#  'ORANGE SCENTED SET/9 T-LIGHTS' 'RECORD FRAME 7" SINGLE SIZE '
#  "POTTING SHED SOW 'N' GROW SET" 'TRAY, BREAKFAST IN BED'
#  'TOAST ITS - HAPPY BIRTHDAY' 'SET/10 IVORY POLKADOT PARTY CANDLES'
#  'SWISS ROLL TOWEL, CHOCOLATE  SPOTS' 'PINK & WHITE BREAKFAST TRAY'
#  'T-LIGHT HOLDER HANGING LACE' "ASS COL SMALL SAND GECKO P'WEIGHT"
#  'MULTI COLOUR SILVER T-LIGHT HOLDER' "CHILDREN'S CIRCUS PARADE MUG"
#  'PACK 3 FIRE ENGINE/CAR PATCHES' 'SET/12 TAPER CANDLES'
#  'SET/4 MODERN VINTAGE COTTON NAPKINS' 'SILVER GLASS T-LIGHT SET'
#  'GIN & TONIC DIET GREETING CARD ' 'BIRTHDAY CARD, RETRO SPOT'
#  'BOOZE & WOMEN GREETING CARD ' "IF YOU CAN'T STAND THE HEAT MUG"
#  '200 RED + WHITE BENDY STRAWS' 'OFFICE MUG WARMER BLACK+SILVER '
#  'T-LIGHT GLASS FLUTED ANTIQUE' 'LARGE HANGING IVORY & RED WOOD BIRD'
#  'SMALL HANGING IVORY/RED WOOD BIRD' 'BLUE CHARLIE+LOLA PERSONAL DOORSIGN'
#  'CHARLIE+LOLA"EXTREMELY BUSY" SIGN' "DOCTOR'S BAG SOFT TOY"
#  'HOOK, 1 HANGER ,MAGIC GARDEN' 'PAINTED LIGHTBULB STAR+ MOON'
#  'FEATHER PEN,COAL BLACK' 'FEATHER PEN,LIGHT PINK' 'FEATHER PEN,HOT PINK'
#  'ART LIGHTS,FUNK MONKEY' 'CERAMIC CAKE STAND + HANGING CAKES'
#  'OFFICE MUG WARMER CHOC+BLUE' 'NURSERY A,B,C PAINTED LETTERS'
#  'CINAMMON & ORANGE WREATH' 'CHRISTMAS GARLAND STARS,TREES'
#  'SMALL HANGING GLASS+ZINC LANTERN' 'SET/3 CHRISTMAS DECOUPAGE CANDLES'
#  'PINK/WHITE CHRISTMAS TREE 60CM' 'EUCALYPTUS & PINECONE  WREATH'
#  'S/4 CACTI CANDLES' '6 CHOCOLATE LOVE HEART T-LIGHTS'
#  'TOAST ITS - BEST MUM' 'CHARLIE+LOLA PINK HOT WATER BOTTLE'
#  'CHARLIE+LOLA RED HOT WATER BOTTLE ' 'COLOUR GLASS. STAR T-LIGHT HOLDER'
#  'LETTER "M" BLING KEY RING' 'LETTER "V" BLING KEY RING'
#  'LETTER "S" BLING KEY RING' 'LETTER "J" BLING KEY RING'
#  'SET/3 VANILLA SCENTED CANDLE IN BOX' 'RIBBON REEL FLORA + FAUNA '
#  'LADYBIRD + BEE RAFFIA FOOD COVER' 'SET/4 GARDEN ROSE DINNER CANDLE'
#  'SET/4 BADGES CUTE CREATURES' 'PINK/YELLOW FLOWERS HANDBAG'
#  'CHARLIE+LOLA MY ROOM DOOR SIGN' 'TOAST ITS - FAIRY FLOWER'
#  'CACTI T-LIGHT CANDLES' 'HANGING BAUBLE T-LIGHT HOLDER SMALL'
#  'TOAST ITS - I LOVE YOU ' 'CAKESTAND, 3 TIER, LOVEHEART'
#  'COFFEE MUG CAT + BIRD DESIGN' 'TEATIME PEN CASE & PENS'
#  'SET/3 RED GINGHAM ROSE STORAGE BOX' 'GLASS HEART T-LIGHT HOLDER '
#  'SET 3 RETROSPOT TEA,COFFEE,SUGAR' 'DECORATION HEN ON NEST, HANGING'
#  'CHARLIE + LOLA BISCUITS TINS' 'SKULLS PARTY BAG + STICKER SET'
#  'SET OF 6 T-LIGHTS WEDDING CAKE ' 'MINI CAKE STAND T-LIGHT HOLDER'
#  'BLACK TEA,COFFEE,SUGAR JARS' 'CARROT CHARLIE+LOLA COASTER SET'
#  'BLACK+WHITE NECKLACE W TASSEL' 'AMBER CHUNKY GLASS+BEAD NECKLACE'
#  "POPPY'S PLAYHOUSE LIVINGROOM " 'FOOD/DRINK SPONGE STICKERS'
#  'HANGING BAUBLE T-LIGHT HOLDER LARGE' 'CUT GLASS HEXAGON T-LIGHT HOLDER'
#  'PINK TALL PORCELAIN T-LIGHT HOLDER '
#  'WHITE TALL PORCELAIN T-LIGHT HOLDER' 'KEY FOB , GARAGE DESIGN'
#  'KEY FOB , FRONT  DOOR ' 'KEY FOB , BACK DOOR '
#  'WRAP, BILLBOARD FONTS DESIGN' 'ELEPHANT, BIRTHDAY CARD, '
#  'MIRROR LOVE BIRD T-LIGHT HOLDER' 'BLACK LOVE BIRD T-LIGHT HOLDER'
#  'HANGING JAM JAR T-LIGHT HOLDER' 'TOAST ITS - DINOSAUR'
#  "FANNY'S REST STOPMETAL SIGN" 'KEY FOB , SHED'
#  'ASSORTED COLOUR T-LIGHT HOLDER' 'CERAMIC CAKE BOWL + HANGING CAKES'
#  'BLUE/CREAM STRIPE CUSHION COVER ' 'DINOSAUR PARTY BAG + STICKER SET'
#  'DECOUPAGE,GREETING CARD,' 'SET/6 BEAD COASTERS GAUZE BAG GOLD'
#  'PORCELAIN T-LIGHT HOLDERS ASSORTED' "POPPY'S PLAYHOUSE BATHROOM"
#  'COFFEE MUG DOG + BALL DESIGN' 'MAGIC TREE -PAPER FLOWERS'
#  'NECKLACE+BRACELET SET FRUIT SALAD ' 'SET/20 STRAWBERRY PAPER NAPKINS '
#  'YULETIDE IMAGES S/6 PAPER BOXES' 'SET/3 FLORAL GARDEN TOOLS IN BAG'
#  'PACK/12 BLUE FOLKART CARDS' 'FOLK ART GREETING CARD,PACK/12'
#  'ASSORTED FLOWER COLOUR "LEIS"' 'PINK/GREEN FLOWER DESIGN BIG MUG'
#  "FLOWER FAIRY,5 SUMMER B'DRAW LINERS" 'BLUE/YELLOW FLOWER DESIGN BIG MUG'
#  'GREEN/BLUE FLOWER DESIGN BIG MUG' 'YELLOW/PINK FLOWER DESIGN BIG MUG'
#  'GARLAND, MAGIC GARDEN 1.8M' 'FOLK ART METAL STAR T-LIGHT HOLDER'
#  'PIG KEYRING WITH LIGHT & SOUND ' 'WOODLAND PARTY BAG + STICKER SET'
#  'BLUE/GREEN SHELL NECKLACE W PENDANT' 'SILVER/NATURAL SHELL NECKLACE'
#  'MOUSE TOY WITH PINK T-SHIRT' 'SET/3 OCEAN SCENT CANDLE JEWEL BOX'
#  "NURSE'S BAG SOFT TOY" 'PINK/WHITE RIBBED MELAMINE JUG'
#  'SET/4 SKULL BADGES' 'SWISS ROLL TOWEL, PINK  SPOTS'
#  'SMALL POP BOX,FUNKY MONKEY' 'SET/6 PURPLE BUTTERFLY T-LIGHTS'
#  "DOLLY MIXTURE CHILDREN'S UMBRELLA" 'PERIWINKLE T-LIGHT HOLDER'
#  'SILICON CUBE 25W, BLUE' 'SET/6 COLLAGE PAPER PLATES'
#  'HANGING HEART JAR T-LIGHT HOLDER' 'PACK 6 HEART/ICE-CREAM PATCHES'
#  'SET/6 TURQUOISE BUTTERFLY T-LIGHTS' 'STRING OF 8 BUTTERFLIES,PINK'
#  'SET/12 FUNKY FELT FLOWER PEG IN BAG' 'SET OF 6 T-LIGHTS EASTER CHICKS'
#  'LARGE CAKE TOWEL, CHOCOLATE SPOTS' 'S/12 MINI RABBIT EASTER'
#  'BLUE & WHITE BREAKFAST TRAY' 'METAL SIGN,CUPCAKE SINGLE HOOK'
#  "RETRO PLASTIC 70'S TRAY" 'RED ROSE AND LACE C/COVER'
#  'SET/4 DAISY MIRROR MAGNETS' 'SET/4 BIRD MIRROR MAGNETS '
#  'SET/4 BUTTERFLY MIRROR MAGNETS' 'PEARL CRYSTAL PUMPKIN T-LIGHT HLDR'
#  'BREAD BIN, DINER STYLE, MINT' 'BREAD BIN, DINER STYLE, IVORY'
#  'SET/6 PINK BIRD T-LIGHT CANDLES' 'S/12 VANILLA  BOTANICAL T-LIGHTS'
#  'FOLDING CAMPING SCISSOR W/KNIF & S' 'HAND OPEN SHAPE DECO.WHITE'
#  'SET OF 6 T-LIGHTS CACTI ' 'SET/3 ROSE CANDLE IN JEWELLED BOX'
#  'SWEETHEART CARRY-ALL BASKET' 'ESSENTIAL BALM 3.5G TIN IN ENVELOPE'
#  'TUMBLER, BAROQUE' 'PINK/WHITE "KEEP CLEAN" BULLET BIN'
#  'SET/4 BADGES BALLOON GIRL' 'TUMBLER, NEW ENGLAND'
#  'SET/6 PINK  BUTTERFLY T-LIGHTS' 'SET/6 GREEN SPRING PAPER CUPS'
#  'SMOKEY GREY COLOUR D.O.F. GLASS' 'S/3 POT POURI CUSHIONS BLUE COLOURS'
#  'SET/3 DECOUPAGE STACKING TINS' 'PACK/12 XMAS FUN CARD'
#  'SET/6 BLACK BIRD T-LIGHT CANDLES' 'SET/6 IVORY BIRD T-LIGHT CANDLES'
#  'EAU DE NILE JEWELLED T-LIGHT HOLDER' 'T-LIGHT HOLDER SWEETHEART HANGING'
#  'CREAM SWEETHEART SHELF + HOOKS' 'LETTER "C" BLING KEY RING'
#  'LETTER "B" BLING KEY RING' 'LETTER "K" BLING KEY RING'
#  'S/4 BLACK MINI ROSE CANDLE IN BOWL' 'HEART T-LIGHT HOLDER'
#  'FOLK ART METAL HEART T-LIGHT HOLDER'
#  'SET/3 TALL GLASS CANDLE HOLDER PINK' 'CLEAR LOVE BIRD T-LIGHT HOLDER'
#  'SET/6 EAU DE NIL BIRD T-LIGHTS' 'CUT GLASS T-LIGHT HOLDER OCTAGON'
#  'SET/4 SPRING FLOWER DECORATION' 'FLOWER GLASS GARLAND NECKL.36"BLACK'
#  'SMALL FOLDING SCISSOR(POINTED EDGE)' 'RETRO "TEA FOR ONE" '
#  'S/4 IVORY MINI ROSE CANDLE IN BOWL' 'SET/4 BLUE FLOWER CANDLES IN BOWL'
#  'SET/4 COLOURFUL MIXING BOWLS' "ASS COL LARGE SAND FROG P'WEIGHT"
#  'FLOWER PURPLE CLOCK W/SUCKER' 'ORIGAMI ROSE INCENSE/CANDLE SET '
#  'ORIGAMI JASMINE INCENSE/CANDLE SET' 'ORIGAMI OPIUM INCENSE/CANDLE SET '
#  'ORIGAMI SANDLEWOOD INCENSE/CAND SET' 'MIRROR MOSAIC T-LIGHT HOLDER '
#  'SILVER/AMETHYST DROP EARRINGS LEAF' 'DOOR HANGER  MUM + DADS ROOM'
#  'GOLD SCROLL GLASS T-LIGHT HOLDER' 'S/4 PINK FLOWER CANDLES IN BOWL'
#  'FLOWER GLASS GARLD NECKL36"AMETHYST' 'TURQ+RED BOUDICCA LARGE BRACELET'
#  'BATHROOM SCALES, TROPICAL BEACH' 'CHARLIE & LOLA WASTEPAPER BIN BLUE'
#  'PINK/WHITE GLASS DEMI CHOKER' 'ZINC HEART LATTICE T-LIGHT HOLDER'
#  'RIDGED GLASS T-LIGHT HOLDER' 'DIAMANTE RING ASSORTED IN BOX.'
#  'ASSTD COL BUTTERFLY/CRYSTAL W/CHIME' 'SET/6 FROG PRINCE T-LIGHT CANDLES'
#  'WHITE TEA,COFFEE,SUGAR JARS' 'SET/4 RED MINI ROSE CANDLE IN BOWL'
#  'ACRYLIC JEWEL SNOWFLAKE,PINK' 'PALE PINK/AMETHYST STONE NECKLACE'
#  'PEARL & SHELL 42"NECKL. GREEN' 'TEAL/FUSCHIA COL BEAD NECKLACE'
#  'S/4 GROOVY CAT MAGNETS' 'PING! MICROWAVE PLATE'
#  'ASSTD FRUIT+FLOWERS FRIDGE MAGNETS'
#  'ORIGAMI LAVENDER INCENSE/CANDL SET '
#  'ORIGAMI VANILLA INCENSE/CANDLE SET ' 'PINK ENAMEL+GLASS HAIR COMB'
#  'SET/4 WHITE RETRO STORAGE CUBES ' 'POLKADOT COFFEE CUP & SAUCER PINK'
#  'ORIGAMI SANDLEWOOD INCENSE+FLOWER' 'SILVER T-LIGHT SETTING'
#  'PINK CHICK EGG WARMER + EGG CUP' 'SET/3 POLKADOT STACKING TINS'
#  'SILVER/MOP ORBIT NECKLACE' 'PURPLE CHUNKY GLASS+BEAD NECKLACE'
#  'PINK BOUDOIR T-LIGHT HOLDER' 'LARGE WHITE/PINK ROSE ART FLOWER'
#  'MEDIUM WHITE/PINK ROSE ART FLOWER' 'DECORATION , WOBBLY RABBIT , METAL '
#  'SET/3 RABBITS FLOWER SKIPPPING ROPE' 'GREETING CARD,SQUARE, DOUGHNUTS'
#  'SILVER M.O.P ORBIT BRACELET' 'LETTER "D" BLING KEY RING'
#  'BOX/12 CHICK & EGG IN BASKET' 'PINK/FLOWER RABBIT EGG WARMER '
#  'SET/3 POT PLANT CANDLES' 'WRAP, CAROUSEL' 'SET/6 COLLAGE PAPER CUPS'
#  'SET/6 FRUIT SALAD PAPER CUPS' 'SET/6 FRUIT SALAD  PAPER PLATES'
#  'GREETING CARD, STICKY GORDON' 'GREETING CARD, OVERCROWDED POOL.'
#  'GREETING CARD, TWO SISTERS.' 'SET/4 BADGES DOGS' 'SET/4 BADGES BEETLES'
#  'PINK CRYSTAL+GLASS BRACELET' 'TURQUOISE CRYSTAL+GLASS BRACELET'
#  'HANGING RIDGE GLASS T-LIGHT HOLDER' 'MIRROR MOSAIC T-LIGHT HOLDER ROUND'
#  'WHITE/PINK CHICK DECORATION' 'DECORATION , WOBBLY CHICKEN, METAL '
#  'BLACK/WHITE GLASS/SILVER BRACELET' 'SET/5 RED SPOTTY LID GLASS BOWLS'
#  'ASSTD RASTA KEY-CHAINS' '3 PINK HEN+CHICKS IN BASKET'
#  '12 PINK HEN+CHICKS IN BASKET' 'HEN HOUSE W FAMILY IN BARN & NEST'
#  'RED/CREAM STRIPE CUSHION COVER ' 'PINK CHERRY BLOSSOM CUP & SAUCER'
#  'DIAMANTE HEART SHAPED WALL MIRROR, ' 'LETTER "R" BLING KEY RING'
#  'SMALL WHITE/PINK ROSE ART FLOWER' 'SET/6 POSIES PAPER PLATES'
#  'VINTAGE ENAMEL & CRYSTAL EARRINGS' 'LETTER "G" BLING KEY RING'
#  'WHITE/PINK CHICK EASTER DECORATION' 'S/2 ZINC HEART DESIGN PLANTERS'
#  'AMBER GLASS/SILVER BRACELET' 'GOLD/M.O.P PENDANT ORBIT NECKLACE'
#  'SILVER/M.O.P PENDANT ORBIT NECKLACE' 'PINK/PURPLE RETRO RADIO'
#  'PET MUG, GOLDFISH' 'NECKLACE+BRACELET PINK BUTTERFLY'
#  'ACRYLIC JEWEL SNOWFLAKE, PINK' 'POCKET MIRROR "GLAMOROUS"'
#  'JADE CRYSTAL+GLASS BRACELET' 'MIDNIGHT BLUE GLASS/SILVER BRACELET'
#  'M/COLOUR POM-POM CURTAIN' 'PINK/PURPLE CIRCLE CURTAIN'
#  'BLUE/NAT SHELL NECKLACE W PENDANT' 'SILVER/NAT SHELL NECKLACE W PENDANT'
#  'SILVER M.O.P ORBIT DROP EARRINGS' 'RETRO PILL BOX , REVOLUTIONARY'
#  'RETRO TIN ASHTRAY,REVOLUTIONARY' 'S/3 PINK SQUARE PLANTERS ROSES'
#  'PURPLE/COPPER HANGING LAMPSHADE' 'GOLD M.O.P ORBIT DROP EARRINGS'
#  "NEW BAROQUE B'FLY NECKLACE CRYSTAL" "NEW BAROQUE B'FLY NECKLACE GREEN"
#  'COPPER/OLIVE GREEN FLOWER NECKLACE' 'GREEN ENAMEL+GLASS HAIR COMB'
#  'T-LIGHT HOLDER WHITE LACE' 'LETTER "A" BLING KEY RING'
#  'NECKLACE+BRACELET SET PINK DAISY' 'NECKLACE+BRACELET SET BLUE BLOSSOM'
#  'SET/6 POSIES PAPER CUPS' 'FELTCRAFT BOY JEAN-PAUL KIT'
#  "MOTHER'S KITCHEN SPOON REST " "CLOCK MAGNET MUM'S KITCHEN"
#  'PINK & WHITE ROSEBUD RING' "MUM'S KITCHEN CLOCK"
#  'S/4 ICON COASTER,ELVIS LIVES' 'DOLLCRAFT BOY JEAN-PAUL '
#  'LETTER "P" BLING KEY RING' 'PURPLE/TURQ FLOWERS HANDBAG'
#  'RUSTIC WOODEN CABINET, GLASS DOORS' 'YELLOW/BLUE RETRO RADIO'
#  'RETRO PILL BOX KEY CHAIN,THE KING' 'WINE BOTTLE DRESSING LT.BLUE'
#  'ANTIQUE SILVER T-LIGHT GLASS' 'ELVIS WALLHANGING / CURTAIN'
#  'FLOWER GLASS GARLD NECKL36"TURQUOIS' 'PINK/AMETHYST/GOLD NECKLACE'
#  'CROCHET BEAR RED/BLUE  KEYRING' 'PACK 4 FLOWER/BUTTERFLY PATCHES'
#  'NECKLACE+BRACELET SET BLUE HIBISCUS' 'ORANGE FELT VASE + FLOWERS'
#  'SILVER/BLACK ORBIT NECKLACE' "NEW BAROQUE B'FLY NECKLACE PINK"
#  'YELLOW/ORANGE FLOWER DESIGN PLATE' 'S/2 BEACH HUT TREASURE CHESTS'
#  'GEMSTONE CHANDELIER T-LIGHT HOLDER' 'BEADED CHANDELIER T-LIGHT HOLDER'
#  'SET OF 12 ROSE BOTANICAL T-LIGHTS' 'IVORY CHANDELIER T-LIGHT HOLDER'
#  'FLOWERS CHANDELIER T-LIGHT HOLDER' 'ZINC T-LIGHT HOLDER STARS SMALL'
#  'ZINC T-LIGHT HOLDER STAR LARGE' 'ORANGE/WHT/FUSCHIA STONES NECKLACE'
#  'WHITE/PINK MINI CRYSTALS NECKLACE' "COTE D'AZURE NECKLACE"
#  'PINK ROSEBUD & PEARL NECKLACE' 'WHITE ROSEBUD & PEARL NECKLACE'
#  'SMALL ZINC/GLASS CANDLEHOLDER' 'BUNTING , SPOTTY '
#  'FOOD COVER WITH BEADS , SET 2 SIZES' 'TURQ STONE/CRYSTAL EARRINGS'
#  'FLOWER GLASS GARLAND NECKL.36"BLUE' 'CRYSTAL CHANDELIER T-LIGHT HOLDER'
#  'ZINC  HEART T-LIGHT HOLDER' 'ZINC HEART FLOWER T-LIGHT HOLDER'
#  'PEARL & SHELL 42"NECKL. IVORY' 'VINTAGE GLASS T-LIGHT HOLDER'
#  'ZINC  STAR T-LIGHT HOLDER ' 'LETTER "Y" BLING KEY RING'
#  'ZINC T-LIGHT HOLDER STARS LARGE' 'ZINC STAR T-LIGHT HOLDER '
#  'DIAMANTE HAIR GRIP PACK/2 LT ROSE' 'SET OF 6 HALLOWEEN GHOST T-LIGHTS'
#  'PINK/BLUE DISC/MIRROR STRING' 'HEART T-LIGHT HOLDER WILLIE WINKIE'
#  'STAR T-LIGHT HOLDER WILLIE WINKIE' 'ACRYLIC JEWEL ICICLE, PINK'
#  'LETTER "E" BLING KEY RING' "BISCUIT TIN 50'S CHRISTMAS"
#  'FOLKART CHRISTMAS TREE T-LIGHT HOLD' 'LETTER "L" BLING KEY RING'
#  'LETTER "N" BLING KEY RING' 'LETTER "H" BLING KEY RING'
#  'FLOWER GLASS GARLAND NECKL.36"GREEN' 'VINTAGE ENAMEL & CRYSTAL NECKLACE'
#  'GOLD/AMBER DROP EARRINGS W LEAF' 'SILVER/CRYSTAL DROP EARRINGS W LEAF'
#  "JUMBO BAG 50'S CHRISTMAS " 'SMALL BONNE JAM JAR  T-LIGHT HOLDER'
#  'T-LIGHT HOLDER SILVER HEART HANDLE'
#  'RIDGED BONNE JAM JAR T-LIGHT HOLDER' 'TREE T-LIGHT HOLDER WILLIE WINKIE'
#  'T-LIGHT HOLDER SILVER PETIT FOUR ' 'LARGE BONNE JAM JAR  T-LIGHT HOLDER'
#  'PINK EASTER HENS+FLOWER' "GIANT 50'S CHRISTMAS CRACKER"
#  "BOX OF 6 MINI 50'S CRACKERS" 'T-LIGHT HOLDER SILVER SAUCER'
#  'ROUND ARTICULATED PINK CLOCK W/SUCK' 'LETTER "I" BLING KEY RING'
#  'PURPLE/BLUE CERAMIC CANDLE HOLDER' 'BLUE/YELLOW CERAMIC CANDLE HOLDER'
#  'GREEN/BLUE CERAMIC CANDLE HOLDER' "WRAP 50'S  CHRISTMAS"
#  'PINK/BLUE STRING CURTAIN ' 'GOLD M.O.P ORBIT BRACELET'
#  'SET OF 12 T-LIGHTS VINTAGE DOILEY' "6 GIFT TAGS 50'S CHRISTMAS "
#  "ROLL WRAP 50'S RED CHRISTMAS " "ROLL WRAP 50'S CHRISTMAS"
#  'PURPLE ENAMEL+GLASS HAIR COMB' 'SET OF 12 T-LIGHTS VINTAGE DOILY'
#  'ACRYLIC JEWEL ANGEL,PINK' 'PINK/WHITE CHRISTMAS TREE 30CM'
#  'ACRYLIC JEWEL ICICLE, BLUE' "50'S CHRISTMAS PAPER GIFT BAG"
#  " 50'S CHRISTMAS GIFT BAG LARGE" "NEW BAROQUE B'FLY NECKLACE RED"
#  'HAPPY BIRTHDAY CARD TEDDY/CAKE' 'ACRYLIC HANGING JEWEL,BLUE'
#  'HANGING JAM JAR T-LIGHT HOLDERS' "PACK OF 12 50'S CHRISTMAS TISSUES"
#  "GIFT BAG LARGE 50'S CHRISTMAS" "3 RAFFIA RIBBONS 50'S CHRISTMAS "
#  'ACRYLIC HANGING JEWEL,PINK' 'PLAYING CARDS KEEP CALM & CARRY ON'
#  'DIAMANTE HAIR GRIP PACK/2 CRYSTAL' 'DIAMANTE HAIR GRIP PACK/2 PERIDOT'
#  'NEW BAROQUE LARGE NECKLACE BLK/WHIT'
#  'HEART TRELLISTRIPLE T-LIGHT HOLDER' 'HORSE & PONY WALL ART'
#  "WALL ART LOVES' SECRET " "70'S ALPHABET WALL ART"
#  'HANGING  BUTTERFLY T-LIGHT HOLDER' "WALL ART 70'S ALPHABET "
#  'WALL ART HORSE & PONY ' 'HEART TRELLIS TRIPLE T-LIGHT HOLDER'
#  "WALL ART , LOVES' SECRET " 'WALL ART,ONLY ONE PERSON '
#  'WALL ART ,PUDDINGS ' 'UBO-LIGHT TRIOBASE PURPLE'
#  'SILVER 2 STRAND NECKLACE-LEAF CHARM' 'DROP EARRINGS W FLOWER & LEAF'
#  'SILVER M.O.P. ORBIT NECKLACE' 'GOLD M.O.P. ORBIT NECKLACE'
#  'WALL ART , THE MAGIC FOREST ' 'PINK HANGING HEART T-LIGHT HOLDER'
#  'T-LIGHT HOLDER HANGING LOVE BIRD' 'GARLAND, VINTAGE BELLS'
#  'TRADITIONAL NAUGHTS & CROSSES' 'UBO-LIGHT TRIOBASE BLUE'
#  'AMBER GLASS/SHELL/PEARL NECKLACE' "BLACK SIL'T SQU CANDLE PLATE "
#  'ROSE FLOWER CANDLE+INCENSE 16X16CM' 'COLOURED GLASS STAR T-LIGHT HOLDER'
#  'WHITE STONE/CRYSTAL EARRINGS' 'CROCHET LILAC/RED BEAR KEYRING'
#  'LETTER "F" BLING KEY RING' 'LETTER "O" BLING KEY RING'
#  'LETTER "T" BLING KEY RING' 'LETTER "U" BLING KEY RING'
#  'LETTER "W" BLING KEY RING' 'LETTER "Z" BLING KEY RING'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']

# %% [markdown]
# **Note:**
#
# *Ensure only one space between words in the Description*

# %%
# Check for rows with multiple spaces in the Description
multiple_spaces = df[df['Description'].str.contains(r'\s{2,}', regex=True)]

# Count occurrences of multiple spaces
print("Occurrences of multiple spaces in the Description:")
print(multiple_spaces.shape[0])
# Out:
# Occurrences of multiple spaces in the Description:
# 16231

# %%
multiple_spaces.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 87     536378    85099C    JUMBO  BAG BAROQUE BLACK WHITE        10
# 128    536381     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 176    536386    85099C    JUMBO  BAG BAROQUE BLACK WHITE       100
# 187    536388     21411       GINGHAM HEART  DOORSTOP RED         3
#
#             InvoiceDate  UnitPrice CustomerID         Country     Status
# 87  2010-12-01 09:37:00       1.95    14688.0  United Kingdom  Completed
# 128 2010-12-01 09:41:00       0.85    15311.0  United Kingdom  Completed
# 154 2010-12-01 09:49:00       4.65    15311.0  United Kingdom  Cancelled
# 176 2010-12-01 09:57:00       1.65    16029.0  United Kingdom  Completed
# 187 2010-12-01 09:59:00       4.25    16250.0  United Kingdom  Completed

# %%
# Replace multiple spaces with a single space in the Description
df['Description'] = df['Description'].str.replace(r'\s+', ' ', regex=True)

# %%
# Check for rows with multiple spaces in the Description
multiple_spaces = df[df['Description'].str.contains(r'\s{2,}', regex=True)]

# Count occurrences of multiple spaces
print("Occurrences of multiple spaces in the Description:")
print(multiple_spaces.shape[0])
# Out:
# Occurrences of multiple spaces in the Description:
# 0

# %% [markdown]
# **Note:**
#
# *Remove dot at the end of the Description*

# %%
# Check for rows where Description ends with a dot
trailing_dots = df[df['Description'].str.endswith('.')]

# Count occurrences of trailing dots
print("Occurrences of trailing dots in the Description:")
print(trailing_dots.shape[0])
# Out:
# Occurrences of trailing dots in the Description:
# 1466

# %%
trailing_dots.head()
# Out:
#     InvoiceNo StockCode                     Description  Quantity  \
# 4      536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 62     536373    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 79     536375    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 292    536396    84029E  RED WOOLLY HOTTIE WHITE HEART.         6
# 413    536404     20727          LUNCH BAG BLACK SKULL.        10
#
#             InvoiceDate  UnitPrice CustomerID         Country     Status
# 4   2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed
# 62  2010-12-01 09:02:00       3.39    17850.0  United Kingdom  Completed
# 79  2010-12-01 09:32:00       3.39    17850.0  United Kingdom  Completed
# 292 2010-12-01 10:51:00       3.39    17850.0  United Kingdom  Completed
# 413 2010-12-01 11:29:00       1.65    16218.0  United Kingdom  Completed

# %%
df['Description'] = df['Description'].str.replace(r'\.$', '', regex=True)

# %%
# Check for rows where Description ends with a dot
trailing_dots = df[df['Description'].str.endswith('.')]

# Count occurrences of trailing dots
print("Occurrences of trailing dots in the Description:")
print(trailing_dots.shape[0])
# Out:
# Occurrences of trailing dots in the Description:
# 0

# %% [markdown]
# **Note:**
#
# *Ensure no space before punctuation*

# %%
# Check for rows with spaces before punctuation
spaces_before_punctuation = df[df['Description'].str.contains(r'\s[,!?]', regex=True)]

# Count occurrences of spaces before punctuation
print("Occurrences of spaces before punctuation in the Description:")
print(spaces_before_punctuation.shape[0])
# Out:
# Occurrences of spaces before punctuation in the Description:
# 930

# %%
spaces_before_punctuation.head()
# Out:
#      InvoiceNo StockCode                   Description  Quantity  \
# 1980   C536548     22245  HOOK, 1 HANGER ,MAGIC GARDEN        -2
# 3370    536623     22245  HOOK, 1 HANGER ,MAGIC GARDEN        24
# 4211    536754     21899       KEY FOB , GARAGE DESIGN         4
# 4215    536754     21902         KEY FOB , FRONT DOOR          4
# 4216    536754     21901          KEY FOB , BACK DOOR          4
#
#              InvoiceDate  UnitPrice CustomerID         Country     Status
# 1980 2010-12-01 14:33:00       0.85    12472.0         Germany  Cancelled
# 3370 2010-12-02 10:39:00       0.85    15601.0  United Kingdom  Completed
# 4211 2010-12-02 14:09:00       0.65    14449.0  United Kingdom  Completed
# 4215 2010-12-02 14:09:00       0.65    14449.0  United Kingdom  Completed
# 4216 2010-12-02 14:09:00       0.65    14449.0  United Kingdom  Completed

# %%
# Ensure no space before punctuation and one space after punctuation
df['Description'] = df['Description'].str.replace(r'\s+([,!?])', r'\1', regex=True)  # Remove space before punctuation

# %%
# Check for rows with spaces before punctuation
spaces_before_punctuation = df[df['Description'].str.contains(r'\s[,!?]', regex=True)]

# Count occurrences of spaces before punctuation
print("Occurrences of spaces before punctuation in the Description:")
print(spaces_before_punctuation.shape[0])
# Out:
# Occurrences of spaces before punctuation in the Description:
# 0

# %% [markdown]
# **Note:**
#
# *Ensure one space after punctuation*

# %%
# Check for rows with missing space after punctuation
missing_space_after_punctuation = df[df['Description'].str.contains(r'[,!?][^\s]', regex=True)]

# Count occurrences of missing space after punctuation
print("Occurrences of missing space after punctuation in the Description:")
print(missing_space_after_punctuation.shape[0])
# Out:
# Occurrences of missing space after punctuation in the Description:
# 1357

# %%
missing_space_after_punctuation.head()
# Out:
#      InvoiceNo StockCode                  Description  Quantity  \
# 109     536381     82567    AIRLINE LOUNGE,METAL SIGN         2
# 1980   C536548     22245  HOOK, 1 HANGER,MAGIC GARDEN        -2
# 2104    536559    51014C       FEATHER PEN,COAL BLACK        24
# 2105    536559    51014L       FEATHER PEN,LIGHT PINK        12
# 2107    536559    51014C       FEATHER PEN,COAL BLACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country     Status
# 109  2010-12-01 09:41:00       2.10    15311.0  United Kingdom  Completed
# 1980 2010-12-01 14:33:00       0.85    12472.0         Germany  Cancelled
# 2104 2010-12-01 14:54:00       0.85    17873.0  United Kingdom  Completed
# 2105 2010-12-01 14:54:00       0.85    17873.0  United Kingdom  Completed
# 2107 2010-12-01 14:54:00       0.85    17873.0  United Kingdom  Completed

# %%
df['Description'] = df['Description'].str.replace(r'([,!?])\s*', r'\1 ', regex=True)  # Ensure one space after punctuation

# %%
# Check for rows with missing space after punctuation
missing_space_after_punctuation = df[df['Description'].str.contains(r'[,!?][^\s]', regex=True)]

# Count occurrences of missing space after punctuation
print("Occurrences of missing space after punctuation in the Description:")
print(missing_space_after_punctuation.shape[0])
# Out:
# Occurrences of missing space after punctuation in the Description:
# 0

# %% [markdown]
# **Note:**
#
# *Remove Leading and Trailing Whitespaces*

# %%
# Check for rows with leading or trailing white spaces
leading_trailing_spaces = df[df['Description'].str.match(r'^\s|\s$', na=False)]

# Count occurrences of leading or trailing white spaces
print("Occurrences of leading or trailing white spaces in the Description:")
print(leading_trailing_spaces.shape[0])
# Out:
# Occurrences of leading or trailing white spaces in the Description:
# 933

# %%
leading_trailing_spaces.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 40     536370     22900   SET 2 TEA TOWELS I LOVE LONDON         24
# 521    536409     22900   SET 2 TEA TOWELS I LOVE LONDON          1
# 611    536412     22900   SET 2 TEA TOWELS I LOVE LONDON          2
# 641    536415     22900   SET 2 TEA TOWELS I LOVE LONDON          3
# 927    536500     22900   SET 2 TEA TOWELS I LOVE LONDON          7
#
#             InvoiceDate  UnitPrice CustomerID         Country     Status
# 40  2010-12-01 08:45:00       2.95    12583.0          France  Completed
# 521 2010-12-01 11:45:00       2.95    17908.0  United Kingdom  Completed
# 611 2010-12-01 11:49:00       2.95    17920.0  United Kingdom  Completed
# 641 2010-12-01 11:57:00       2.95    12838.0  United Kingdom  Completed
# 927 2010-12-01 12:35:00       2.95    17377.0  United Kingdom  Completed

# %%
# Remove leading and trailing white spaces
df['Description'] = df['Description'].str.strip()

# %%
# Check for rows with leading or trailing white spaces
leading_trailing_spaces = df[df['Description'].str.match(r'^\s|\s$', na=False)]

# Count occurrences of leading or trailing white spaces
print("Occurrences of leading or trailing white spaces in the Description:")
print(leading_trailing_spaces.shape[0])
# Out:
# Occurrences of leading or trailing white spaces in the Description:
# 0

# %% [markdown]
# **Note:**
#
# *Changing "+", "&" to "AND"*

# %%
# Filter rows where Description contains "+"
descriptions_with_symbols = df[df['Description'].str.contains(r'[+]', na=False)]

# Get unique descriptions with "+"
unique_descriptions_with_symbols = descriptions_with_symbols['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with '+':")
print(unique_descriptions_with_symbols)
# Out:
# Unique Descriptions with '+':
# ['TOMATO CHARLIE+LOLA COASTER SET' 'RED CHARLIE+LOLA PERSONAL DOORSIGN'
#  'GIN + TONIC DIET METAL SIGN' 'REX CASH+CARRY JUMBO SHOPPER'
#  'CHARLIE + LOLA RED HOT WATER BOTTLE' 'RETROSPOT PARTY BAG + STICKER SET'
#  '200 RED + WHITE BENDY STRAWS' 'OFFICE MUG WARMER BLACK+SILVER'
#  'BLUE CHARLIE+LOLA PERSONAL DOORSIGN' 'CHARLIE+LOLA"EXTREMELY BUSY" SIGN'
#  'PAINTED LIGHTBULB STAR+ MOON' 'CERAMIC CAKE STAND + HANGING CAKES'
#  'OFFICE MUG WARMER CHOC+BLUE' 'SMALL HANGING GLASS+ZINC LANTERN'
#  'CHARLIE+LOLA PINK HOT WATER BOTTLE' 'CHARLIE+LOLA RED HOT WATER BOTTLE'
#  'RIBBON REEL FLORA + FAUNA' 'LADYBIRD + BEE RAFFIA FOOD COVER'
#  'CHARLIE+LOLA MY ROOM DOOR SIGN' 'COFFEE MUG CAT + BIRD DESIGN'
#  'CHARLIE + LOLA BISCUITS TINS' 'SKULLS PARTY BAG + STICKER SET'
#  'CARROT CHARLIE+LOLA COASTER SET' 'BLACK+WHITE NECKLACE W TASSEL'
#  'AMBER CHUNKY GLASS+BEAD NECKLACE' 'CERAMIC CAKE BOWL + HANGING CAKES'
#  'DINOSAUR PARTY BAG + STICKER SET' 'COFFEE MUG DOG + BALL DESIGN'
#  'NECKLACE+BRACELET SET FRUIT SALAD' 'WOODLAND PARTY BAG + STICKER SET'
#  'CREAM SWEETHEART SHELF + HOOKS' 'DOOR HANGER MUM + DADS ROOM'
#  'TURQ+RED BOUDICCA LARGE BRACELET' 'ASSTD FRUIT+FLOWERS FRIDGE MAGNETS'
#  'PINK ENAMEL+GLASS HAIR COMB' 'ORIGAMI SANDLEWOOD INCENSE+FLOWER'
#  'PINK CHICK EGG WARMER + EGG CUP' 'PURPLE CHUNKY GLASS+BEAD NECKLACE'
#  'PINK CRYSTAL+GLASS BRACELET' 'TURQUOISE CRYSTAL+GLASS BRACELET'
#  '3 PINK HEN+CHICKS IN BASKET' '12 PINK HEN+CHICKS IN BASKET'
#  'NECKLACE+BRACELET PINK BUTTERFLY' 'JADE CRYSTAL+GLASS BRACELET'
#  'GREEN ENAMEL+GLASS HAIR COMB' 'NECKLACE+BRACELET SET PINK DAISY'
#  'NECKLACE+BRACELET SET BLUE BLOSSOM'
#  'NECKLACE+BRACELET SET BLUE HIBISCUS' 'ORANGE FELT VASE + FLOWERS'
#  'PINK EASTER HENS+FLOWER' 'PURPLE ENAMEL+GLASS HAIR COMB'
#  'ROSE FLOWER CANDLE+INCENSE 16X16CM']

# %%
# Count occurrences of unique descriptions with "+"
print("Count of Unique Descriptions with '+':")
print(len(unique_descriptions_with_symbols))
# Out:
# Count of Unique Descriptions with '+':
# 52

# %%
# Replace " + " with " AND "
df['Description'] = df['Description'].str.replace(r'\s\+\s', ' AND ', regex=True)
# Replace "+" with " AND "
df['Description'] = df['Description'].str.replace(r'\+', ' AND ', regex=True)
# Replace " +" with " AND "
df['Description'] = df['Description'].str.replace(r'\s\+', ' AND ', regex=True)
# Replace "+ " with " AND "
df['Description'] = df['Description'].str.replace(r'\+\s', ' AND ', regex=True)

# %%
# Filter rows where Description contains "+"
descriptions_with_symbols = df[df['Description'].str.contains(r'[+]', na=False)]

# Get unique descriptions with "+"
unique_descriptions_with_symbols = descriptions_with_symbols['Description'].unique()

# Count occurrences of unique descriptions with "+"
print("Count of Unique Descriptions with '+':")
print(len(unique_descriptions_with_symbols))
# Out:
# Count of Unique Descriptions with '+':
# 0

# %%
# Filter rows where Description contains "&"
descriptions_with_symbols = df[df['Description'].str.contains(r'[&]', na=False)]

# Get unique descriptions with "&"
unique_descriptions_with_symbols = descriptions_with_symbols['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with '&':")
print(unique_descriptions_with_symbols)
# Out:
# Unique Descriptions with '&':
# ['CHARLIE & LOLA WASTEPAPER BIN FLORA' 'VINTAGE SNAKES & LADDERS'
#  'LADIES & GENTLEMEN METAL SIGN' 'PINK & WHITE BREAKFAST TRAY'
#  'GIN & TONIC DIET GREETING CARD' 'BOOZE & WOMEN GREETING CARD'
#  'LARGE HANGING IVORY & RED WOOD BIRD' 'CINAMMON & ORANGE WREATH'
#  'EUCALYPTUS & PINECONE WREATH' 'TEATIME PEN CASE & PENS'
#  'PIG KEYRING WITH LIGHT & SOUND' 'BLUE & WHITE BREAKFAST TRAY'
#  'FOLDING CAMPING SCISSOR W/KNIF & S' 'CHARLIE & LOLA WASTEPAPER BIN BLUE'
#  'PEARL & SHELL 42"NECKL. GREEN' 'POLKADOT COFFEE CUP & SAUCER PINK'
#  'BOX/12 CHICK & EGG IN BASKET' 'HEN HOUSE W FAMILY IN BARN & NEST'
#  'PINK CHERRY BLOSSOM CUP & SAUCER' 'VINTAGE ENAMEL & CRYSTAL EARRINGS'
#  'PINK & WHITE ROSEBUD RING' 'PINK ROSEBUD & PEARL NECKLACE'
#  'WHITE ROSEBUD & PEARL NECKLACE' 'PEARL & SHELL 42"NECKL. IVORY'
#  'VINTAGE ENAMEL & CRYSTAL NECKLACE' 'PLAYING CARDS KEEP CALM & CARRY ON'
#  'HORSE & PONY WALL ART' 'WALL ART HORSE & PONY'
#  'DROP EARRINGS W FLOWER & LEAF' 'TRADITIONAL NAUGHTS & CROSSES']

# %%
# Count occurrences of unique descriptions with "&"
print("Count of Unique Descriptions with '&':")
print(len(unique_descriptions_with_symbols))
# Out:
# Count of Unique Descriptions with '&':
# 30

# %%
# Replace " & " with " AND "
df['Description'] = df['Description'].str.replace(r'\s&\s', ' AND ', regex=True)

# %%
# Filter rows where Description contains "&"
descriptions_with_symbols = df[df['Description'].str.contains(r'[&]', na=False)]

# Get unique descriptions with "&"
unique_descriptions_with_symbols = descriptions_with_symbols['Description'].unique()

# Count occurrences of unique descriptions with "&"
print("Count of Unique Descriptions with '&':")
print(len(unique_descriptions_with_symbols))
# Out:
# Count of Unique Descriptions with '&':
# 0

# %% [markdown]
# **Note:**
#
# *Changing "W" to "WITH"*

# %%
# Filter rows where Description contains " W "
descriptions_with_w = df[df['Description'].str.contains(r'\sW\s', na=False)]

# Get unique descriptions with " W "
unique_descriptions_with_w = descriptions_with_w['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with ' W ':")
print(unique_descriptions_with_w)
# Out:
# Unique Descriptions with ' W ':
# ['SET 3 WICKER OVAL BASKETS W LIDS' "PINK B'FLY C/COVER W BOBBLES"
#  'BLACK AND WHITE NECKLACE W TASSEL' 'BLUE/GREEN SHELL NECKLACE W PENDANT'
#  'FRENCH ENAMEL POT W LID' 'NEW ENGLAND MUG W GIFT BOX'
#  'BLACK FINE BEAD NECKLACE W TASSEL' 'HAND TOWEL PALE BLUE W FLOWERS'
#  'BLUE ORGANDY ROUND LAMPSHADE W BEA'
#  'AMETHYST CHUNKY BEAD BRACELET W STR'
#  'AMBER CHUNKY BEAD BRACELET W STRAP' 'HEN HOUSE W CHICK STANDING'
#  'FINE SILVER NECKLACE W PASTEL FLOWE' 'AMBER FINE BEAD NECKLACE W TASSEL'
#  'LAZER CUT NECKLACE W PASTEL BEADS' 'PINK SCOTTIE DOG W FLOWER PATTERN'
#  'BLUE SCOTTIE DOG W FLOWER PATTERN' 'BLACK CHUNKY BEAD BRACELET W STRAP'
#  'RESIN BRACELET W PASTEL BEADS' 'RESIN NECKLACE W PASTEL BEADS'
#  'HEN HOUSE W FAMILY IN BARN AND NEST'
#  'BLACK GLASS BRACELET W HEART CHARMS' 'ELEPHANT CLIP W SUCTION CUP'
#  'PURPLE AMETHYST NECKLACE W TASSEL' 'BLUE/NAT SHELL NECKLACE W PENDANT'
#  'SILVER/NAT SHELL NECKLACE W PENDANT' 'JADE DROP EARRINGS W FILIGREE'
#  'SILVER BRACELET W PASTEL FLOWER' 'PINK FELT HANGING HEART W FLOWER'
#  'BEACH HUT SHELF W 3 DRAWERS' 'BLACK DROP EARRINGS W LONG BEADS'
#  'YELLOW FELT HANGING HEART W FLOWER' 'HEN HOUSE W CHICK IN NEST'
#  'BLUE CHECK BAG W HANDLE 34X20CM' 'RASTA IN BATH W SPLIFF ASHTRAY'
#  'GOLD/AMBER DROP EARRINGS W LEAF' 'SILVER/CRYSTAL DROP EARRINGS W LEAF'
#  'GREEN DROP EARRINGS W BEAD CLUSTER' '3 BLACK CATS W HEARTS BLANK CARD'
#  'AMBER DROP EARRINGS W LONG BEADS' 'DROP EARRINGS W FLOWER AND LEAF']

# %%
# Count occurrences of unique descriptions with " W "
print("Count of Unique Descriptions with ' W ':")
print(len(unique_descriptions_with_w))
# Out:
# Count of Unique Descriptions with ' W ':
# 41

# %%
# Replace " W " with " WITH "
df['Description'] = df['Description'].str.replace(r'\sW\s', ' WITH ', regex=True)

# %%
# Filter rows where Description contains " W "
descriptions_with_w = df[df['Description'].str.contains(r'\sW\s', na=False)]

# Get unique descriptions with " W "
unique_descriptions_with_w = descriptions_with_w['Description'].unique()

# Count occurrences of unique descriptions with " W "
print("Count of Unique Descriptions with ' W ':")
print(len(unique_descriptions_with_w))
# Out:
# Count of Unique Descriptions with ' W ':
# 0

# %% [markdown]
# **Note:**
#
# *Changing "/" to "OR"*

# %%
# Filter rows where Description contains "/" but not followed by a number
descriptions_with_slash = df[df['Description'].str.contains(r'/\D', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with '/' not followed by a number:")
print(unique_descriptions_with_slash)
# Out:
# Unique Descriptions with '/' not followed by a number:
# ['VINTAGE BILLBOARD LOVE/HATE MUG' 'BLACK/BLUE POLKADOT UMBRELLA'
#  "PINK B'FLY C/COVER WITH BOBBLES" 'FOLDING UMBRELLA WHITE/RED POLKADOT'
#  'FOLDING UMBRELLA RED/WHITE POLKADOT' 'PACK 3 FIRE ENGINE/CAR PATCHES'
#  'SMALL HANGING IVORY/RED WOOD BIRD' 'PINK/WHITE CHRISTMAS TREE 60CM'
#  'PINK/YELLOW FLOWERS HANDBAG' 'FOOD/DRINK SPONGE STICKERS'
#  'BLUE/CREAM STRIPE CUSHION COVER' 'PINK/GREEN FLOWER DESIGN BIG MUG'
#  'BLUE/YELLOW FLOWER DESIGN BIG MUG' 'GREEN/BLUE FLOWER DESIGN BIG MUG'
#  'YELLOW/PINK FLOWER DESIGN BIG MUG'
#  'BLUE/GREEN SHELL NECKLACE WITH PENDANT' 'SILVER/NATURAL SHELL NECKLACE'
#  'PINK/WHITE RIBBED MELAMINE JUG' 'PACK 6 HEART/ICE-CREAM PATCHES'
#  'RED ROSE AND LACE C/COVER' 'FOLDING CAMPING SCISSOR W/KNIF AND S'
#  'PINK/WHITE "KEEP CLEAN" BULLET BIN' 'FLOWER PURPLE CLOCK W/SUCKER'
#  'ORIGAMI ROSE INCENSE/CANDLE SET' 'ORIGAMI JASMINE INCENSE/CANDLE SET'
#  'ORIGAMI OPIUM INCENSE/CANDLE SET' 'ORIGAMI SANDLEWOOD INCENSE/CAND SET'
#  'SILVER/AMETHYST DROP EARRINGS LEAF' 'PINK/WHITE GLASS DEMI CHOKER'
#  'ASSTD COL BUTTERFLY/CRYSTAL W/CHIME' 'PALE PINK/AMETHYST STONE NECKLACE'
#  'TEAL/FUSCHIA COL BEAD NECKLACE' 'ORIGAMI LAVENDER INCENSE/CANDL SET'
#  'ORIGAMI VANILLA INCENSE/CANDLE SET' 'SILVER/MOP ORBIT NECKLACE'
#  'LARGE WHITE/PINK ROSE ART FLOWER' 'MEDIUM WHITE/PINK ROSE ART FLOWER'
#  'PINK/FLOWER RABBIT EGG WARMER' 'WHITE/PINK CHICK DECORATION'
#  'BLACK/WHITE GLASS/SILVER BRACELET' 'RED/CREAM STRIPE CUSHION COVER'
#  'SMALL WHITE/PINK ROSE ART FLOWER' 'WHITE/PINK CHICK EASTER DECORATION'
#  'AMBER GLASS/SILVER BRACELET' 'GOLD/M.O.P PENDANT ORBIT NECKLACE'
#  'SILVER/M.O.P PENDANT ORBIT NECKLACE' 'PINK/PURPLE RETRO RADIO'
#  'MIDNIGHT BLUE GLASS/SILVER BRACELET' 'M/COLOUR POM-POM CURTAIN'
#  'PINK/PURPLE CIRCLE CURTAIN' 'BLUE/NAT SHELL NECKLACE WITH PENDANT'
#  'SILVER/NAT SHELL NECKLACE WITH PENDANT'
#  'PURPLE/COPPER HANGING LAMPSHADE' 'COPPER/OLIVE GREEN FLOWER NECKLACE'
#  'PURPLE/TURQ FLOWERS HANDBAG' 'YELLOW/BLUE RETRO RADIO'
#  'ELVIS WALLHANGING / CURTAIN' 'PINK/AMETHYST/GOLD NECKLACE'
#  'CROCHET BEAR RED/BLUE KEYRING' 'PACK 4 FLOWER/BUTTERFLY PATCHES'
#  'SILVER/BLACK ORBIT NECKLACE' 'YELLOW/ORANGE FLOWER DESIGN PLATE'
#  'ORANGE/WHT/FUSCHIA STONES NECKLACE' 'WHITE/PINK MINI CRYSTALS NECKLACE'
#  'SMALL ZINC/GLASS CANDLEHOLDER' 'TURQ STONE/CRYSTAL EARRINGS'
#  'PINK/BLUE DISC/MIRROR STRING' 'GOLD/AMBER DROP EARRINGS WITH LEAF'
#  'SILVER/CRYSTAL DROP EARRINGS WITH LEAF'
#  'ROUND ARTICULATED PINK CLOCK W/SUCK' 'PURPLE/BLUE CERAMIC CANDLE HOLDER'
#  'BLUE/YELLOW CERAMIC CANDLE HOLDER' 'GREEN/BLUE CERAMIC CANDLE HOLDER'
#  'PINK/BLUE STRING CURTAIN' 'PINK/WHITE CHRISTMAS TREE 30CM'
#  'HAPPY BIRTHDAY CARD TEDDY/CAKE' 'NEW BAROQUE LARGE NECKLACE BLK/WHIT'
#  'AMBER GLASS/SHELL/PEARL NECKLACE' 'WHITE STONE/CRYSTAL EARRINGS'
#  'CROCHET LILAC/RED BEAR KEYRING']

# %%
# Count occurrences of unique descriptions with "/"
print("Count of Unique Descriptions with '/' not followed by a number:")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with '/' not followed by a number:
# 80

# %%
# Replace "/" with " OR " where "/" is not followed by a number
df['Description'] = df['Description'].str.replace(r'/(?=\D)', ' OR ', regex=True)

# %%
# Filter rows where Description contains "/" but not followed by a number
descriptions_with_slash = df[df['Description'].str.contains(r'/\D', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Count occurrences of unique descriptions with "/"
print("Count of Unique Descriptions with '/' not followed by a number:")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with '/' not followed by a number:
# 0

# %% [markdown]
# **Note:**
#
# *Changing "S/" to "SET "*

# %%
# Filter rows where Description contains "/"
descriptions_with_slash = df[df['Description'].str.contains(r'S/', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with '/':")
print(unique_descriptions_with_slash)
# Out:
# Unique Descriptions with '/':
# ['WOOD S/3 CABINET ANT WHITE FINISH' 'S/6 SEW ON CROCHET FLOWERS'
#  'S/4 VALENTINE DECOUPAGE HEART BOX' 'S/6 WOODEN SKITTLES IN COTTON BAG'
#  'S/15 SILVER GLASS BAUBLES IN BAG' 'S/4 CACTI CANDLES'
#  'YULETIDE IMAGES S/6 PAPER BOXES' 'S/12 MINI RABBIT EASTER'
#  'S/12 VANILLA BOTANICAL T-LIGHTS' 'S/3 POT POURI CUSHIONS BLUE COLOURS'
#  'S/4 BLACK MINI ROSE CANDLE IN BOWL' 'S/4 IVORY MINI ROSE CANDLE IN BOWL'
#  'S/4 PINK FLOWER CANDLES IN BOWL' 'S/4 GROOVY CAT MAGNETS'
#  'S/2 ZINC HEART DESIGN PLANTERS' 'S/3 PINK SQUARE PLANTERS ROSES'
#  'S/4 ICON COASTER, ELVIS LIVES' 'S/2 BEACH HUT TREASURE CHESTS']

# %%
# Count occurrences of unique descriptions with "S/"
print("Count of Unique Descriptions with 'S/':")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with 'S/':
# 18

# %%
# Replace " S/ " with " SET "
df['Description'] = df['Description'].str.replace(r'S/', 'SET OF ', regex=True)

# %%
# Filter rows where Description contains "/"
descriptions_with_slash = df[df['Description'].str.contains(r'S/', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Count occurrences of unique descriptions with "S/"
print("Count of Unique Descriptions with 'S/':")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with 'S/':
# 0

# %% [markdown]
# **Note:**
#
# *Changing "/" to space*

# %%
# Filter rows where Description contains "/"
descriptions_with_slash = df[df['Description'].str.contains(r'/', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with '/':")
print(unique_descriptions_with_slash)
# Out:
# Unique Descriptions with '/':
# ['SET/2 RED RETROSPOT TEA TOWELS' 'SET/6 RED SPOTTY PAPER PLATES'
#  'SET/20 RED RETROSPOT PAPER NAPKINS' 'SET/6 RED SPOTTY PAPER CUPS'
#  'SET/10 PINK POLKADOT PARTY CANDLES'
#  'SET/5 RED RETROSPOT LID GLASS BOWLS' 'SET/10 RED POLKADOT PARTY CANDLES'
#  'DIAMANTE HAIR GRIP PACK/2 BLACK DIA' 'DIAMANTE HAIR GRIP PACK/2 RUBY'
#  'DIAMANTE HAIR GRIP PACK/2 MONTANA' 'SET/10 BLUE POLKADOT PARTY CANDLES'
#  'SET/9 CHRISTMAS T-LIGHTS SCENTED' 'ORANGE SCENTED SET/9 T-LIGHTS'
#  'SET/10 IVORY POLKADOT PARTY CANDLES' 'SET/12 TAPER CANDLES'
#  'SET/4 MODERN VINTAGE COTTON NAPKINS' 'SET/3 CHRISTMAS DECOUPAGE CANDLES'
#  'SET/3 VANILLA SCENTED CANDLE IN BOX' 'SET/4 GARDEN ROSE DINNER CANDLE'
#  'SET/4 BADGES CUTE CREATURES' 'SET/3 RED GINGHAM ROSE STORAGE BOX'
#  'SET/6 BEAD COASTERS GAUZE BAG GOLD' 'SET/20 STRAWBERRY PAPER NAPKINS'
#  'SET/3 FLORAL GARDEN TOOLS IN BAG' 'PACK/12 BLUE FOLKART CARDS'
#  'FOLK ART GREETING CARD, PACK/12' 'SET/3 OCEAN SCENT CANDLE JEWEL BOX'
#  'SET/4 SKULL BADGES' 'SET/6 PURPLE BUTTERFLY T-LIGHTS'
#  'SET/6 COLLAGE PAPER PLATES' 'SET/6 TURQUOISE BUTTERFLY T-LIGHTS'
#  'SET/12 FUNKY FELT FLOWER PEG IN BAG' 'SET/4 DAISY MIRROR MAGNETS'
#  'SET/4 BIRD MIRROR MAGNETS' 'SET/4 BUTTERFLY MIRROR MAGNETS'
#  'SET/6 PINK BIRD T-LIGHT CANDLES' 'SET/3 ROSE CANDLE IN JEWELLED BOX'
#  'SET/4 BADGES BALLOON GIRL' 'SET/6 PINK BUTTERFLY T-LIGHTS'
#  'SET/6 GREEN SPRING PAPER CUPS' 'SET/3 DECOUPAGE STACKING TINS'
#  'PACK/12 XMAS FUN CARD' 'SET/6 BLACK BIRD T-LIGHT CANDLES'
#  'SET/6 IVORY BIRD T-LIGHT CANDLES' 'SET/3 TALL GLASS CANDLE HOLDER PINK'
#  'SET/6 EAU DE NIL BIRD T-LIGHTS' 'SET/4 SPRING FLOWER DECORATION'
#  'SET/4 BLUE FLOWER CANDLES IN BOWL' 'SET/4 COLOURFUL MIXING BOWLS'
#  'SET/6 FROG PRINCE T-LIGHT CANDLES' 'SET/4 RED MINI ROSE CANDLE IN BOWL'
#  'SET/4 WHITE RETRO STORAGE CUBES' 'SET/3 POLKADOT STACKING TINS'
#  'SET/3 RABBITS FLOWER SKIPPPING ROPE' 'BOX/12 CHICK AND EGG IN BASKET'
#  'SET/3 POT PLANT CANDLES' 'SET/6 COLLAGE PAPER CUPS'
#  'SET/6 FRUIT SALAD PAPER CUPS' 'SET/6 FRUIT SALAD PAPER PLATES'
#  'SET/4 BADGES DOGS' 'SET/4 BADGES BEETLES'
#  'SET/5 RED SPOTTY LID GLASS BOWLS' 'SET/6 POSIES PAPER PLATES'
#  'SET/6 POSIES PAPER CUPS' 'DIAMANTE HAIR GRIP PACK/2 LT ROSE'
#  'DIAMANTE HAIR GRIP PACK/2 CRYSTAL' 'DIAMANTE HAIR GRIP PACK/2 PERIDOT']

# %%
# Count occurrences of unique descriptions with "/"
print("Count of Unique Descriptions with '/':")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with '/':
# 67

# %%
# Replace "/" with " "
df['Description'] = df['Description'].str.replace(r'/', ' OF ', regex=True)

# %%
# Filter rows where Description contains "/"
descriptions_with_slash = df[df['Description'].str.contains(r'/', na=False)]

# Get unique descriptions with "/"
unique_descriptions_with_slash = descriptions_with_slash['Description'].unique()

# Count occurrences of unique descriptions with "/"
print("Count of Unique Descriptions with '/':")
print(len(unique_descriptions_with_slash))
# Out:
# Count of Unique Descriptions with '/':
# 0

# %%
# Filter rows where Description contains punctuations
punctuation_descriptions = df[df['Description'].str.contains(r'[^\w\s]', na=False)]

# Get unique descriptions with punctuations
unique_punctuation_descriptions = punctuation_descriptions['Description'].unique()

# Display the unique descriptions
print("Unique Descriptions with Punctuations:")
print(unique_punctuation_descriptions)
# Out:
# Unique Descriptions with Punctuations:
# ['WHITE HANGING HEART T-LIGHT HOLDER' 'GLASS STAR FROSTED T-LIGHT HOLDER'
#  "POPPY'S PLAYHOUSE BEDROOM" "POPPY'S PLAYHOUSE KITCHEN"
#  "PAPER CHAIN KIT 50'S CHRISTMAS" 'RED HANGING HEART T-LIGHT HOLDER'
#  'AIRLINE LOUNGE, METAL SIGN' "YOU'RE CONFUSING ME METAL SIGN"
#  'COLOUR GLASS T-LIGHT HOLDER HANGING' 'HANGING HEART ZINC T-LIGHT HOLDER'
#  'FANCY FONT BIRTHDAY CARD,' "I'M ON HOLIDAY METAL SIGN"
#  'SET OF 6 T-LIGHTS SNOWMEN' 'SET OF 6 T-LIGHTS SANTA'
#  'VICTORIAN GLASS HANGING T-LIGHT' 'SINGLE HEART ZINC T-LIGHT HOLDER'
#  'SILVER HANGING T-LIGHT HOLDER' 'ROTATING SILVER ANGELS T-LIGHT HLDR'
#  "CHILDREN'S SPACEBOY MUG" 'BLACK CANDELABRA T-LIGHT HOLDER'
#  'SET 12 LAVENDER BOTANICAL T-LIGHTS' "PINK B'FLY C OR COVER WITH BOBBLES"
#  'AGED GLASS SILVER T-LIGHT HOLDER' "CHILDREN'S APRON DOLLY GIRL"
#  'SET OF 6 T-LIGHTS TOADSTOOLS' 'ROTATING LEAVES T-LIGHT HOLDER'
#  'HYACINTH BULB T-LIGHT CANDLES' 'CHRISTMAS TREE T-LIGHT HOLDER'
#  'STAR T-LIGHT HOLDER' 'HEART T-LIGHT HOLDER'
#  'SET OF 9 CHRISTMAS T-LIGHTS SCENTED' 'CINAMMON SET OF 9 T-LIGHTS'
#  'ORANGE SCENTED SET OF 9 T-LIGHTS' 'RECORD FRAME 7" SINGLE SIZE'
#  "POTTING SHED SOW 'N' GROW SET" 'TRAY, BREAKFAST IN BED'
#  'TOAST ITS - HAPPY BIRTHDAY' 'SWISS ROLL TOWEL, CHOCOLATE SPOTS'
#  'T-LIGHT HOLDER HANGING LACE' "ASS COL SMALL SAND GECKO P'WEIGHT"
#  'MULTI COLOUR SILVER T-LIGHT HOLDER' "CHILDREN'S CIRCUS PARADE MUG"
#  'SILVER GLASS T-LIGHT SET' 'BIRTHDAY CARD, RETRO SPOT'
#  "IF YOU CAN'T STAND THE HEAT MUG" 'T-LIGHT GLASS FLUTED ANTIQUE'
#  'CHARLIE AND LOLA"EXTREMELY BUSY" SIGN' "DOCTOR'S BAG SOFT TOY"
#  'HOOK, 1 HANGER, MAGIC GARDEN' 'FEATHER PEN, COAL BLACK'
#  'FEATHER PEN, LIGHT PINK' 'FEATHER PEN, HOT PINK'
#  'ART LIGHTS, FUNK MONKEY' 'NURSERY A, B, C PAINTED LETTERS'
#  'CHRISTMAS GARLAND STARS, TREES' '6 CHOCOLATE LOVE HEART T-LIGHTS'
#  'TOAST ITS - BEST MUM' 'COLOUR GLASS. STAR T-LIGHT HOLDER'
#  'LETTER "M" BLING KEY RING' 'LETTER "V" BLING KEY RING'
#  'LETTER "S" BLING KEY RING' 'LETTER "J" BLING KEY RING'
#  'TOAST ITS - FAIRY FLOWER' 'CACTI T-LIGHT CANDLES'
#  'HANGING BAUBLE T-LIGHT HOLDER SMALL' 'TOAST ITS - I LOVE YOU'
#  'CAKESTAND, 3 TIER, LOVEHEART' 'GLASS HEART T-LIGHT HOLDER'
#  'SET 3 RETROSPOT TEA, COFFEE, SUGAR' 'DECORATION HEN ON NEST, HANGING'
#  'SET OF 6 T-LIGHTS WEDDING CAKE' 'MINI CAKE STAND T-LIGHT HOLDER'
#  'BLACK TEA, COFFEE, SUGAR JARS' "POPPY'S PLAYHOUSE LIVINGROOM"
#  'HANGING BAUBLE T-LIGHT HOLDER LARGE' 'CUT GLASS HEXAGON T-LIGHT HOLDER'
#  'PINK TALL PORCELAIN T-LIGHT HOLDER'
#  'WHITE TALL PORCELAIN T-LIGHT HOLDER' 'KEY FOB, GARAGE DESIGN'
#  'KEY FOB, FRONT DOOR' 'KEY FOB, BACK DOOR' 'WRAP, BILLBOARD FONTS DESIGN'
#  'ELEPHANT, BIRTHDAY CARD,' 'MIRROR LOVE BIRD T-LIGHT HOLDER'
#  'BLACK LOVE BIRD T-LIGHT HOLDER' 'HANGING JAM JAR T-LIGHT HOLDER'
#  'TOAST ITS - DINOSAUR' "FANNY'S REST STOPMETAL SIGN" 'KEY FOB, SHED'
#  'ASSORTED COLOUR T-LIGHT HOLDER' 'DECOUPAGE, GREETING CARD,'
#  'PORCELAIN T-LIGHT HOLDERS ASSORTED' "POPPY'S PLAYHOUSE BATHROOM"
#  'MAGIC TREE -PAPER FLOWERS' 'FOLK ART GREETING CARD, PACK OF 12'
#  'ASSORTED FLOWER COLOUR "LEIS"' "FLOWER FAIRY, 5 SUMMER B'DRAW LINERS"
#  'GARLAND, MAGIC GARDEN 1.8M' 'FOLK ART METAL STAR T-LIGHT HOLDER'
#  'MOUSE TOY WITH PINK T-SHIRT' "NURSE'S BAG SOFT TOY"
#  'SWISS ROLL TOWEL, PINK SPOTS' 'SMALL POP BOX, FUNKY MONKEY'
#  'SET OF 6 PURPLE BUTTERFLY T-LIGHTS' "DOLLY MIXTURE CHILDREN'S UMBRELLA"
#  'PERIWINKLE T-LIGHT HOLDER' 'SILICON CUBE 25W, BLUE'
#  'HANGING HEART JAR T-LIGHT HOLDER' 'PACK 6 HEART OR ICE-CREAM PATCHES'
#  'SET OF 6 TURQUOISE BUTTERFLY T-LIGHTS' 'STRING OF 8 BUTTERFLIES, PINK'
#  'SET OF 6 T-LIGHTS EASTER CHICKS' 'LARGE CAKE TOWEL, CHOCOLATE SPOTS'
#  'METAL SIGN, CUPCAKE SINGLE HOOK' "RETRO PLASTIC 70'S TRAY"
#  'PEARL CRYSTAL PUMPKIN T-LIGHT HLDR' 'BREAD BIN, DINER STYLE, MINT'
#  'BREAD BIN, DINER STYLE, IVORY' 'SET OF 6 PINK BIRD T-LIGHT CANDLES'
#  'SET OF 12 VANILLA BOTANICAL T-LIGHTS' 'HAND OPEN SHAPE DECO.WHITE'
#  'SET OF 6 T-LIGHTS CACTI' 'SWEETHEART CARRY-ALL BASKET'
#  'ESSENTIAL BALM 3.5G TIN IN ENVELOPE' 'TUMBLER, BAROQUE'
#  'PINK OR WHITE "KEEP CLEAN" BULLET BIN' 'TUMBLER, NEW ENGLAND'
#  'SET OF 6 PINK BUTTERFLY T-LIGHTS' 'SMOKEY GREY COLOUR D.O.F. GLASS'
#  'SET OF 6 BLACK BIRD T-LIGHT CANDLES'
#  'SET OF 6 IVORY BIRD T-LIGHT CANDLES'
#  'EAU DE NILE JEWELLED T-LIGHT HOLDER' 'T-LIGHT HOLDER SWEETHEART HANGING'
#  'LETTER "C" BLING KEY RING' 'LETTER "B" BLING KEY RING'
#  'LETTER "K" BLING KEY RING' 'FOLK ART METAL HEART T-LIGHT HOLDER'
#  'CLEAR LOVE BIRD T-LIGHT HOLDER' 'SET OF 6 EAU DE NIL BIRD T-LIGHTS'
#  'CUT GLASS T-LIGHT HOLDER OCTAGON' 'FLOWER GLASS GARLAND NECKL.36"BLACK'
#  'SMALL FOLDING SCISSOR(POINTED EDGE)' 'RETRO "TEA FOR ONE"'
#  "ASS COL LARGE SAND FROG P'WEIGHT" 'MIRROR MOSAIC T-LIGHT HOLDER'
#  'GOLD SCROLL GLASS T-LIGHT HOLDER' 'FLOWER GLASS GARLD NECKL36"AMETHYST'
#  'BATHROOM SCALES, TROPICAL BEACH' 'ZINC HEART LATTICE T-LIGHT HOLDER'
#  'RIDGED GLASS T-LIGHT HOLDER' 'SET OF 6 FROG PRINCE T-LIGHT CANDLES'
#  'WHITE TEA, COFFEE, SUGAR JARS' 'ACRYLIC JEWEL SNOWFLAKE, PINK'
#  'PEARL AND SHELL 42"NECKL. GREEN' 'PING! MICROWAVE PLATE'
#  'SILVER T-LIGHT SETTING' 'PINK BOUDOIR T-LIGHT HOLDER'
#  'DECORATION, WOBBLY RABBIT, METAL' 'GREETING CARD, SQUARE, DOUGHNUTS'
#  'SILVER M.O.P ORBIT BRACELET' 'LETTER "D" BLING KEY RING'
#  'WRAP, CAROUSEL' 'GREETING CARD, STICKY GORDON'
#  'GREETING CARD, OVERCROWDED POOL' 'GREETING CARD, TWO SISTERS'
#  'HANGING RIDGE GLASS T-LIGHT HOLDER' 'MIRROR MOSAIC T-LIGHT HOLDER ROUND'
#  'DECORATION, WOBBLY CHICKEN, METAL' 'ASSTD RASTA KEY-CHAINS'
#  'DIAMANTE HEART SHAPED WALL MIRROR,' 'LETTER "R" BLING KEY RING'
#  'LETTER "G" BLING KEY RING' 'GOLD OR M.O.P PENDANT ORBIT NECKLACE'
#  'SILVER OR M.O.P PENDANT ORBIT NECKLACE' 'PET MUG, GOLDFISH'
#  'POCKET MIRROR "GLAMOROUS"' 'M OR COLOUR POM-POM CURTAIN'
#  'SILVER M.O.P ORBIT DROP EARRINGS' 'RETRO PILL BOX, REVOLUTIONARY'
#  'RETRO TIN ASHTRAY, REVOLUTIONARY' 'GOLD M.O.P ORBIT DROP EARRINGS'
#  "NEW BAROQUE B'FLY NECKLACE CRYSTAL" "NEW BAROQUE B'FLY NECKLACE GREEN"
#  'T-LIGHT HOLDER WHITE LACE' 'LETTER "A" BLING KEY RING'
#  'FELTCRAFT BOY JEAN-PAUL KIT' "MOTHER'S KITCHEN SPOON REST"
#  "CLOCK MAGNET MUM'S KITCHEN" "MUM'S KITCHEN CLOCK"
#  'SET OF 4 ICON COASTER, ELVIS LIVES' 'DOLLCRAFT BOY JEAN-PAUL'
#  'LETTER "P" BLING KEY RING' 'RUSTIC WOODEN CABINET, GLASS DOORS'
#  'RETRO PILL BOX KEY CHAIN, THE KING' 'WINE BOTTLE DRESSING LT.BLUE'
#  'ANTIQUE SILVER T-LIGHT GLASS' 'FLOWER GLASS GARLD NECKL36"TURQUOIS'
#  "NEW BAROQUE B'FLY NECKLACE PINK" 'GEMSTONE CHANDELIER T-LIGHT HOLDER'
#  'BEADED CHANDELIER T-LIGHT HOLDER' 'SET OF 12 ROSE BOTANICAL T-LIGHTS'
#  'IVORY CHANDELIER T-LIGHT HOLDER' 'FLOWERS CHANDELIER T-LIGHT HOLDER'
#  'ZINC T-LIGHT HOLDER STARS SMALL' 'ZINC T-LIGHT HOLDER STAR LARGE'
#  "COTE D'AZURE NECKLACE" 'BUNTING, SPOTTY'
#  'FOOD COVER WITH BEADS, SET 2 SIZES' 'FLOWER GLASS GARLAND NECKL.36"BLUE'
#  'CRYSTAL CHANDELIER T-LIGHT HOLDER' 'ZINC HEART T-LIGHT HOLDER'
#  'ZINC HEART FLOWER T-LIGHT HOLDER' 'PEARL AND SHELL 42"NECKL. IVORY'
#  'VINTAGE GLASS T-LIGHT HOLDER' 'ZINC STAR T-LIGHT HOLDER'
#  'LETTER "Y" BLING KEY RING' 'ZINC T-LIGHT HOLDER STARS LARGE'
#  'SET OF 6 HALLOWEEN GHOST T-LIGHTS' 'HEART T-LIGHT HOLDER WILLIE WINKIE'
#  'STAR T-LIGHT HOLDER WILLIE WINKIE' 'ACRYLIC JEWEL ICICLE, PINK'
#  'LETTER "E" BLING KEY RING' "BISCUIT TIN 50'S CHRISTMAS"
#  'FOLKART CHRISTMAS TREE T-LIGHT HOLD' 'LETTER "L" BLING KEY RING'
#  'LETTER "N" BLING KEY RING' 'LETTER "H" BLING KEY RING'
#  'FLOWER GLASS GARLAND NECKL.36"GREEN' "JUMBO BAG 50'S CHRISTMAS"
#  'SMALL BONNE JAM JAR T-LIGHT HOLDER' 'T-LIGHT HOLDER SILVER HEART HANDLE'
#  'RIDGED BONNE JAM JAR T-LIGHT HOLDER' 'TREE T-LIGHT HOLDER WILLIE WINKIE'
#  'T-LIGHT HOLDER SILVER PETIT FOUR' 'LARGE BONNE JAM JAR T-LIGHT HOLDER'
#  "GIANT 50'S CHRISTMAS CRACKER" "BOX OF 6 MINI 50'S CRACKERS"
#  'T-LIGHT HOLDER SILVER SAUCER' 'LETTER "I" BLING KEY RING'
#  "WRAP 50'S CHRISTMAS" 'GOLD M.O.P ORBIT BRACELET'
#  'SET OF 12 T-LIGHTS VINTAGE DOILEY' "6 GIFT TAGS 50'S CHRISTMAS"
#  "ROLL WRAP 50'S RED CHRISTMAS" "ROLL WRAP 50'S CHRISTMAS"
#  'SET OF 12 T-LIGHTS VINTAGE DOILY' 'ACRYLIC JEWEL ANGEL, PINK'
#  'ACRYLIC JEWEL ICICLE, BLUE' "50'S CHRISTMAS PAPER GIFT BAG"
#  "50'S CHRISTMAS GIFT BAG LARGE" "NEW BAROQUE B'FLY NECKLACE RED"
#  'ACRYLIC HANGING JEWEL, BLUE' 'HANGING JAM JAR T-LIGHT HOLDERS'
#  "PACK OF 12 50'S CHRISTMAS TISSUES" "GIFT BAG LARGE 50'S CHRISTMAS"
#  "3 RAFFIA RIBBONS 50'S CHRISTMAS" 'ACRYLIC HANGING JEWEL, PINK'
#  'HEART TRELLISTRIPLE T-LIGHT HOLDER' "WALL ART LOVES' SECRET"
#  "70'S ALPHABET WALL ART" 'HANGING BUTTERFLY T-LIGHT HOLDER'
#  "WALL ART 70'S ALPHABET" 'HEART TRELLIS TRIPLE T-LIGHT HOLDER'
#  "WALL ART, LOVES' SECRET" 'WALL ART, ONLY ONE PERSON'
#  'WALL ART, PUDDINGS' 'UBO-LIGHT TRIOBASE PURPLE'
#  'SILVER 2 STRAND NECKLACE-LEAF CHARM' 'SILVER M.O.P. ORBIT NECKLACE'
#  'GOLD M.O.P. ORBIT NECKLACE' 'WALL ART, THE MAGIC FOREST'
#  'PINK HANGING HEART T-LIGHT HOLDER' 'T-LIGHT HOLDER HANGING LOVE BIRD'
#  'GARLAND, VINTAGE BELLS' 'UBO-LIGHT TRIOBASE BLUE'
#  "BLACK SIL'T SQU CANDLE PLATE" 'COLOURED GLASS STAR T-LIGHT HOLDER'
#  'LETTER "F" BLING KEY RING' 'LETTER "O" BLING KEY RING'
#  'LETTER "T" BLING KEY RING' 'LETTER "U" BLING KEY RING'
#  'LETTER "W" BLING KEY RING' 'LETTER "Z" BLING KEY RING'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT, LITTLE BIRDIE']

# %% [markdown]
# #### *6. Checking UnitPrice*

# %%
# Filter rows where UnitPrice is 0
unitprice_zero_rows = df[df['UnitPrice'] == 0]

# Display the filtered rows
unitprice_zero_rows.head()
# Out:
#       InvoiceNo StockCode                   Description  Quantity  \
# 9302     537197     22841  ROUND CAKE TIN VINTAGE GREEN         1
# 33576    539263     22580  ADVENT CALENDAR GINGHAM SACK         4
# 40089    539722     22423      REGENCY CAKESTAND 3 TIER        10
# 47068    540372     22090       PAPER BUNTING RETROSPOT        24
# 47070    540372     22553        PLASTERS IN TIN SKULLS        24
#
#               InvoiceDate  UnitPrice CustomerID         Country     Status
# 9302  2010-12-05 14:02:00        0.0    12647.0         Germany  Completed
# 33576 2010-12-16 14:36:00        0.0    16560.0  United Kingdom  Completed
# 40089 2010-12-21 13:45:00        0.0    14911.0            EIRE  Completed
# 47068 2011-01-06 16:41:00        0.0    13081.0  United Kingdom  Completed
# 47070 2011-01-06 16:41:00        0.0    13081.0  United Kingdom  Completed

# %%
print(f"Number of rows before removing UnitPrice = 0: {df.shape[0]}")

# Remove rows where UnitPrice is 0
df = df[df['UnitPrice'] != 0]

# Verify the changes
print(f"Number of rows after removing UnitPrice = 0: {df.shape[0]}")
# Out:
# Number of rows before removing UnitPrice = 0: 399606
# Number of rows after removing UnitPrice = 0: 399573

# %%
# Filter rows where UnitPrice is 0
unitprice_lessthan_zero_rows = df[df['UnitPrice'] < 0]

# Display the filtered rows
unitprice_lessthan_zero_rows.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Status]
# Index: []

# %% [markdown]
# #### *7. Checking CustomerID*

# %%
df_play['CustomerID'] = df_play['CustomerID'].astype(str)

# Count the number of numeric characters in each CustomerID
df_play['CustomerID_NumericLength'] = df_play['CustomerID'].apply(lambda x: sum(c.isdigit() for c in x))

# Count unique CustomerID based on their numeric length
numeric_length_counts = df_play.groupby('CustomerID_NumericLength')['CustomerID'].nunique()

print("Unique CustomerID counts based on numeric length:")
display(numeric_length_counts)
# Out:
# Unique CustomerID counts based on numeric length:
# CustomerID_NumericLength
# 6    4372
# Name: CustomerID, dtype: int64

# %%
# Count CustomerID with alphabetic characters
customerid_with_alphabets = df_play[df_play['CustomerID'].str.contains('[a-zA-Z]', na=False)]
alphabet_count = customerid_with_alphabets['CustomerID'].nunique()

print(f"Count of CustomerID with alphabetic characters: {alphabet_count}")
# Out:
# Count of CustomerID with alphabetic characters: 0

# %% [markdown]
# #### *8. Checking Country*

# %%
# Display unique countries and their value counts
country_counts = df['Country'].value_counts()

print("Unique countries and their value counts:")
display(country_counts)
# Out:
# Unique countries and their value counts:
# Country
# United Kingdom          356008
# Germany                   9079
# France                    8152
# EIRE                      7368
# Spain                     2462
# Netherlands               2326
# Belgium                   1971
# Switzerland               1843
# Portugal                  1427
# Australia                 1253
# Norway                    1059
# Italy                      783
# Channel Islands            752
# Finland                    653
# Cyprus                     608
# Sweden                     436
# Austria                    387
# Denmark                    375
# Japan                      355
# Poland                     336
# USA                        291
# Israel                     247
# Unspecified                241
# Singapore                  215
# Iceland                    182
# Canada                     150
# Greece                     142
# Malta                      123
# United Arab Emirates        67
# European Community          58
# RSA                         57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              28
# Bahrain                     17
# Saudi Arabia                10
# Name: count, dtype: int64

# %% [markdown]
# ### **Final Dataset**

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E        RED WOOLLY HOTTIE WHITE HEART         6
#
#           InvoiceDate  UnitPrice CustomerID         Country     Status
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom  Completed
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom  Completed
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom  Completed

# %%
# Save the dataset as a CSV file
df.to_csv('data/prepared_data.csv', index=False)
